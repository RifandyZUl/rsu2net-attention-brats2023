# %% [markdown]
# ## Import Libraries

# %%
# !pip install itk --quiet
# !pip install itkwidgets --quiet
# !pip install ipywidgets --quiet

# %%
# import itk
# import itkwidgets
import cv2
import imageio
from tensorflow.keras.utils import to_categorical
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
from IPython.display import clear_output, Image
import tensorflow as tf
from tensorflow import keras
import json
import os
import pickle
import scipy.ndimage
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from IPython.display import display, HTML
from tqdm import tqdm

# %%
# !pip list > dependencies.txt

# %%
import tensorflow as tf
print(f'Versi TensorFlow: {tf.__version__}')
# Out:
# Versi TensorFlow: 2.19.0

# %% [markdown]
# ## Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BASE_DIR = '/content/drive/MyDrive/Kelly/100p_brats2023'

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# #### Data

# %%
img1_path = BASE_DIR + '/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/imagesTr/K23_1250_0002.nii.gz'
img_obj = nib.load(img1_path)
print(f'Tipe data image: {type(img_obj)}')
# Out:
# Tipe data image: <class 'nibabel.nifti1.Nifti1Image'>

# %%
img_data = img_obj.get_fdata()
type(img_data)
height, width, depth = img_data.shape
print(f'Shape gambar: height: {height}, width: {width}, depth: {depth}')
print(f'Dimensi data: {np.ndim(img_data)}')
# Out:
# Shape gambar: height: 240, width: 240, depth: 155
# Dimensi data: 3

# %% [markdown]
# #### Visualisasi Data

# %%
vol_depth = 154
i = np.random.randint(0,vol_depth)
channel = 2

print(f'Menampilkan slice gambar {i} dengan saluran: {channel}')
plt.imshow(img_data[:,:,i], cmap='gray')
# plt.axis('off')
# Out:
# Menampilkan slice gambar 25 dengan saluran: 2

# %%
BASE_CASE = '/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/imagesTr/K23_1250'

i = 80

modalities = {
    "t2f":   BASE_CASE + "_0000.nii.gz",
    "t1n":     BASE_CASE + "_0001.nii.gz",
    "t1c":   BASE_CASE + "_0002.nii.gz",
    "t2w":     BASE_CASE + "_0003.nii.gz"
}

imgs = {name: nib.load(path).get_fdata() for name, path in modalities.items()}

fig, axes = plt.subplots(1, 4, figsize=(15, 5))
for ax, (name, data) in zip(axes, imgs.items()):
    ax.imshow(data[:, :, i], cmap='gray')
    ax.set_title(name)
    ax.axis('off')

plt.suptitle(f'Slice ke-{i} dari empat modalitas', fontsize=16)
plt.show()

# %% [markdown]
# #### Interactive Visualisasi Data

# %%
BASE_CASE = '/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/imagesTr/K23_1250'
modalities = [
    ("t2f", BASE_CASE + "_0000.nii.gz"),
    ("t1n",   BASE_CASE + "_0001.nii.gz"),
    ("t1c",  BASE_CASE + "_0002.nii.gz"),
    ("t2w",   BASE_CASE + "_0003.nii.gz"),
]

vols = []
labels = []
for label, path in modalities:
    img = nib.load(path).get_fdata()
    vols.append(img)
    labels.append(label)

vol4d = np.stack(vols, axis=-1)

def img3d_explore(layer, channel=0):
    clear_output(wait=True)
    plt.figure(figsize=(6,6))
    plt.imshow(vol4d[:, :, layer, channel], cmap='gray')
    plt.title(f'Modality {channel} | Slice {layer}', fontsize=14)
    plt.axis('off')
    plt.show()
    return layer

interact(
    img3d_explore,
    layer=(0, vol4d.shape[2]-1),
    channel=(0, vol4d.shape[3]-1)
)
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), IntSlider(value=0, description='chann…
# <function __main__.img3d_explore(layer, channel=0)>

# %% [markdown]
# #### Label

# %%
label1_path = BASE_DIR + '/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/labelsTr/K23_1249.nii.gz'
label_obj = nib.load(label1_path)
type(label_obj)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
label_data = label_obj.get_fdata()
type(label_data)
height, width, depth = label_data.shape
print(f'Shape label: height: {height}, width: {width}, depth: {depth}')
# Out:
# Shape label: height: 240, width: 240, depth: 155

# %%
print(f'Nilai Unik pada label: {np.unique(label_data)}')
# Out:
# Nilai Unik pada label: [0. 1. 2. 3.]

# %%
print(np.where(label_data == 2))
# Out:
# (array([ 54,  54,  54, ..., 118, 118, 118]), array([146, 146, 147, ..., 138, 138, 138]), array([60, 61, 60, ..., 84, 85, 86]))

# %% [markdown]
# #### Visualisasi Label

# %%
layer = 80
class_dict = {
    'Necrotic Tumor Core': 1.,
    'Peritumoral Edema': 2.,
    'Enhancing Tumor': 3.
}

fig, ax = plt.subplots(nrows=1, ncols = 3, figsize=(50,10))
for i in range (3):
  img_label = list(class_dict.keys())[i]
  img = label_data[:,:,layer]
  mask = np.where(img==class_dict[img_label], 255,0)
  ax[i].imshow(mask, cmap='gray')
  ax[i].set_title(f'{img_label}', fontsize = 40)
  ax[i].axis('off')

plt.tight_layout()

# %% [markdown]
# #### Interactive Visualisasi Label

# %%
select_class = ToggleButtons(
    options=['Necrotic Tumor Core', 'Peritumoral Edema', 'Enhancing Tumor'],
    description='Pilih Class:',
    disabled=False,
    button_style='info'
)
select_layer = IntSlider(min=0, max=154, description='Pilih Layer', continuous_update=False)

def plot_image(seg_class, layer):
    clear_output(wait=True)
    print(f'Menampilkan layer {layer} | Label: {seg_class}')
    img_label = class_dict[seg_class]
    mask = np.where(label_data[:, :, layer] == img_label, 255, 0)
    plt.figure(figsize=(10,5))
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

interactive(plot_image, seg_class=select_class, layer=select_layer)
# Out:
# interactive(children=(ToggleButtons(button_style='info', description='Pilih Class:', options=('Necrotic Tumor …

# %% [markdown]
# #### Visualisasi 3D

# %%
# import numpy as np
# import nibabel as nib
# from mayavi import mlab

# # Run in pycharm
# BASE_CASE = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/imagesTr/K23_1250"
# image_flair = nib.load(BASE_CASE + "_0000.nii.gz").get_fdata()
# label = nib.load("/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/labelsTr/K23_1250.nii.gz").get_fdata()

# if image_flair.ndim == 4:
#     image_flair = image_flair[..., 0]

# mlab.figure(bgcolor=(0, 0, 0), size=(800, 600))

# src_image = mlab.pipeline.volume(
#     mlab.pipeline.scalar_field(image_flair),
#     color=(1, 1, 1)
# )

# color_map = {
#     1: (1, 0, 0),  # NCR = red
#     2: (0, 1, 0),  # ED = green
#     3: (0, 0, 1)   # ET = blue
# }

# for label_class, color in color_map.items():
#     labeled_volume = np.where(label == label_class, 1, 0)
#     src = mlab.pipeline.volume(
#         mlab.pipeline.scalar_field(labeled_volume),
#         color=color
#     )

# mlab.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ##### Voxel dan Standarisasi

# %%
import glob
import os

BASE_PATH = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023"
label_files = sorted(glob.glob(os.path.join(BASE_DIR, "labelsTr", "*.nii.gz")))


label_files = sorted(
    glob.glob(os.path.join(BASE_PATH, "labelsTr", "*.nii.gz"))
)
print("Found label files:", len(label_files))

if label_files:
    lbl_file = label_files[0]
    print("Example label file:", lbl_file)

    label = nib.load(lbl_file).get_fdata()
    print("Shape:", label.shape)

total_voxels = np.prod(label.shape)
tumor_voxels = np.sum(label > 0)
print("Tumor ratio:", tumor_voxels / total_voxels)
# Out:
# Found label files: 1251
# Example label file: /content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/labelsTr/K23_0000.nii.gz
# Shape: (240, 240, 155)
# Tumor ratio: 0.006418570788530466

# %%
def standarisasi(image):
  standarisasi_image = np.zeros(image.shape)
  for c in range(image.shape[0]):
    for z in range(image.shape[3]):
      image_slice = image[c,:,:,z]
      centered = image_slice - np.mean(image_slice)
      centered_scaled = centered / np.std(centered)
      standarisasi_image[c,:,:,z] = centered_scaled
  return standarisasi_image

def get_sub_volume(image, label,
                   orig_x = 240, orig_y = 240, orig_z = 155,
                   output_x = 160, output_y = 160, output_z = 16,
                   num_classes = 4, max_tries = 100,
                   background_threshold=0.995):
  X = None
  y = None
  start_x = None
  start_y = None
  start_z = None

  tries = 0
  while tries < max_tries:
    start_x = np.random.randint(0 , orig_x - output_x + 1)
    start_y = np.random.randint(0 , orig_y - output_y + 1)
    start_z = np.random.randint(0 , orig_z - output_z + 1)

    y = label[start_x: start_x + output_x,
              start_y: start_y + output_y,
              start_z: start_z + output_z]

    y = to_categorical(y, num_classes = num_classes)

    bgrd_ratio = np.sum(y[:,:,:,0]) / (output_x * output_y * output_z)

    tries += 1

    if bgrd_ratio < background_threshold:

        X = np.copy(image[start_x: start_x + output_x,
                          start_y: start_y + output_y,
                          start_z: start_z + output_z, :])

        X = np.moveaxis(X,3,0)
        X = standarisasi(X)
        y = np.moveaxis(y,3,0)
        y = y[1:, :, :, :]

        return X, y, start_x, start_y, start_z

    print(f"Percobaan ke-{tries} untuk menemukan sub-volume")

# %% [markdown]
# Crop preprocessed segmentation

# %%
# from tqdm import tqdm
# import os, pickle, numpy as np, nibabel as nib, scipy.ndimage

# PP_stage = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_preprocessed/Task001_BraTS2023/nnUNetData_plans_v2.1_trgSp_1x1x1_stage0"
# PP_gt    = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_preprocessed/Task001_BraTS2023/gt_segmentations"
# OUT_DIR  = "/content/drive/MyDrive/Kelly/RSUU2Net/sub_volumes"
# os.makedirs(OUT_DIR, exist_ok=True)

# pkl_files = sorted([f for f in os.listdir(PP_stage) if f.endswith(".pkl")])

# for pkl_file in tqdm(pkl_files, desc="Rebuilding seg masks (canonical → crop → resample)"):
#     case_id  = pkl_file[:-4]
#     pkl_path = os.path.join(PP_stage, pkl_file)
#     seg_path = os.path.join(PP_gt, f"{case_id}.nii.gz")

#     with open(pkl_path, "rb") as f:
#         meta = pickle.load(f)
#     (x1,x2), (y1,y2), (z1,z2) = meta["crop_bbox"]
#     target_shape = tuple(meta["size_after_resampling"])

#     seg_ras = nib.as_closest_canonical(nib.load(seg_path)).get_fdata().astype(np.uint8)

#     seg_crop = seg_ras[x1:x2, y1:y2, z1:z2]

#     zoom = np.array(target_shape) / np.array(seg_crop.shape)
#     seg_resampled = scipy.ndimage.zoom(seg_crop, zoom=zoom, order=0)

#     np.save(os.path.join(OUT_DIR, f"{case_id}_seg.npy"), seg_resampled)

# print(f"Done. Saved to {OUT_DIR}")

# %%
# import numpy as np, matplotlib.pyplot as plt

# case_id   = "K23_1239"
# stage_dir = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_preprocessed/Task001_BraTS2023/nnUNetData_plans_v2.1_trgSp_1x1x1_stage0"
# seg_dir   = "/content/drive/MyDrive/Kelly/RSUU2Net/sub_volumes"

# image = np.load(f"{stage_dir}/{case_id}.npz")["data"]         # (C, X, Y, Z)
# seg   = np.load(f"{seg_dir}/{case_id}_seg.npy")               # (X, Y, Z)

# print("Image shape:", image.shape)
# print("Seg shape:",   seg.shape)

# modality = 0                       # pick the channel you want to view
# z = seg.shape[-1] // 2             # middle slice
# mri = image[modality, :, :, z]
# mask = seg[:, :, z]

# plt.figure(figsize=(6,6))
# plt.imshow(mri, cmap="gray")
# plt.imshow(np.ma.masked_where(mask == 0, mask), cmap="jet", alpha=0.5)
# plt.title(f"Case {case_id} | Modality {modality} | Slice {z}")
# plt.axis("off")
# plt.show()

# %% [markdown]
# ##### Menyimpan Voxel

# %%
# import os
# import glob
# import nibabel as nib
# import numpy as np
# import h5py
# import json


# def stack_modalities(case_id, base_dir):
#     """Stack 4 modality files (0000–0003) into one 4D array (H,W,D,4)."""
#     files = [
#         f"{base_dir}/imagesTr/{case_id}_0000.nii.gz",
#         f"{base_dir}/imagesTr/{case_id}_0001.nii.gz",
#         f"{base_dir}/imagesTr/{case_id}_0002.nii.gz",
#         f"{base_dir}/imagesTr/{case_id}_0003.nii.gz"
#     ]
#     vols = [nib.load(f).get_fdata() for f in files]
#     return np.stack(vols, axis=-1)


# def load_data(img_file, lbl_file):
#     if isinstance(img_file, str):
#         image = np.array(nib.load(img_file).get_fdata())
#     else:
#         image = img_file
#     label = np.array(nib.load(lbl_file).get_fdata())
#     return image, label


# def save_sub_volumes_all_images(num_sub_volumes, output_dir, case_id, base_dir, lbl_file, max_attempts=50):
#     if not os.path.exists(output_dir):
#         os.makedirs(output_dir)

#     image = stack_modalities(case_id, base_dir)
#     label = np.array(nib.load(lbl_file).get_fdata())

#     sub_volume_generated = False
#     attempts = 0

#     for i in range(1, num_sub_volumes+1):
#         sub_vol = get_sub_volume(image, label)

#         while (sub_vol is not None and np.isnan(sub_vol[0]).any()) and attempts < max_attempts:
#             print(f"Sub-volume {i} for {case_id} Terdapat nan value. Generate yang baru.")
#             sub_vol = get_sub_volume(image, label)
#             attempts += 1

#         if attempts == max_attempts or sub_vol is None:
#             print(f"Gagal mendapatkan sub-volume tanpa NaN setelah {max_attempts} atau sub volume adalah None. Melanjutkan ke gambar berikutnya.")
#             break

#         X, y, start_x, start_y, start_z = sub_vol
#         h5_file = os.path.join(
#             output_dir,
#             f"{case_id}_{i}_x{start_x}_y{start_y}_z{start_z}.h5"
#         )
#         with h5py.File(h5_file, 'w') as hf:
#             hf.create_dataset('x', data=X, compression='gzip', compression_opts=9)
#             hf.create_dataset('y', data=y, compression='gzip', compression_opts=9)

#         sub_volume_generated = True

#     if not sub_volume_generated:
#         print(f"Tidak ada sub-volume yang memenuhi kriteria untuk {case_id}")


# BASE_DIR = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023"
# OUTPUT_DIR = "/content/drive/MyDrive/Kelly/RSUU2Net/sub_volume"

# label_files = sorted(glob.glob(os.path.join(BASE_DIR, "labelsTr", "*.nii.gz")))
# cases = [os.path.basename(f).replace(".nii.gz", "") for f in label_files]

# for case_id, lbl_file in zip(cases, label_files):
#     print(f"Processing {case_id} ...")
#     save_sub_volumes_all_images(5, OUTPUT_DIR, case_id, BASE_DIR, lbl_file)

# %%
import h5py
def visualize_patch(X, y):
    fig, ax = plt.subplots(1, 2, figsize=[10, 5], squeeze=False)

    ax[0][0].imshow(X[:, :, 0], cmap='gray')
    ax[0][0].set_yticks([])
    ax[0][0].set_xticks([])
    ax[0][1].imshow(y[:, :, 0], cmap='viridis')
    ax[0][1].set_xticks([])
    ax[0][1].set_yticks([])

    fig.subplots_adjust(wspace=0, hspace=0)

file_name = '/content/drive/MyDrive/Kelly/RSUU2Net/sub_volume/K23_1250_5_x50_y68_z84.h5'

with h5py.File(file_name, 'r') as hf:
    image_data = hf['x'][:]
    label_data = hf['y'][:]
print(image_data.shape)
print(label_data.shape)
visualize_patch(image_data[2], label_data[0])

plt.show()
# Out:
# (4, 160, 160, 16)
# (3, 160, 160, 16)

# %%
# import os
# import shutil
# import random
# import json

# all_dir = '/content/drive/MyDrive/Kelly/RSUU2Net/sub_volume'
# temp_dir = '/content/RSUU2Net_splits'
# train_dir = os.path.join(temp_dir, 'training')
# val_dir   = os.path.join(temp_dir, 'validation')
# test_dir  = os.path.join(temp_dir, 'testing')

# for d in [train_dir, val_dir, test_dir]:
#     os.makedirs(d, exist_ok=True)

# all_h5_files = [f for f in os.listdir(all_dir) if f.endswith('.h5')]

# def get_case_id(filename):
#     return "_".join(filename.split("_")[:2])

# case_ids = sorted(set(get_case_id(f) for f in all_h5_files))

# random.seed(42)
# random.shuffle(case_ids)

# n_total = len(case_ids)
# n_train = int(0.7 * n_total)
# n_val   = int(0.15 * n_total)
# n_test  = n_total - n_train - n_val

# train_cases = case_ids[:n_train]
# val_cases   = case_ids[n_train:n_train+n_val]
# test_cases  = case_ids[n_train+n_val:]

# train_files, val_files, test_files = [], [], []

# for f in all_h5_files:
#     case_id = get_case_id(f)
#     src = os.path.join(all_dir, f)
#     if case_id in train_cases:
#         shutil.copy(src, os.path.join(train_dir, f))
#         train_files.append(f)
#     elif case_id in val_cases:
#         shutil.copy(src, os.path.join(val_dir, f))
#         val_files.append(f)
#     else:
#         shutil.copy(src, os.path.join(test_dir, f))
#         test_files.append(f)

# final_data = {
#     "training": sorted(train_files),
#     "validation": sorted(val_files),
#     "testing": sorted(test_files)
# }

# config_path = os.path.join(temp_dir, "configurasi.json")
# with open(config_path, 'w') as json_file:
#     json.dump(final_data, json_file, indent=4)

# print(f"Split {n_total} cases into {n_train} train, {n_val} val, {n_test} test.")
# print("Saved locally at:", temp_dir)

# drive_target = "/content/drive/MyDrive/Kelly/RSUU2Net"
# shutil.copytree(temp_dir, drive_target, dirs_exist_ok=True)
# print(f"Copied results back to Drive: {drive_target}")

# %%
import os
import json

direktori_train = '/content/drive/MyDrive/Kelly/RSUU2Net/training'
direktori_val = '/content/drive/MyDrive/Kelly/RSUU2Net/validation'
direktori_test = '/content/drive/MyDrive/Kelly/RSUU2Net/testing'

def collect_h5_files(directory):
    h5_files = [file for file in os.listdir(directory) if file.endswith(".h5")]
    return sorted(h5_files)

train_h5_files = collect_h5_files(direktori_train)
val_h5_files = collect_h5_files(direktori_val)
test_h5_files = collect_h5_files(direktori_test)

final_data = {"training": train_h5_files, "validation": val_h5_files, "testing": test_h5_files}

with open('configurasi.json', 'w') as json_file:
    json.dump(final_data, json_file, indent=4)

# %%
import os
import matplotlib.pyplot as plt
import random

def get_case_id(filename):
    return "_".join(filename.split("_")[:2])

def get_unique_cases(directory):
    files = [f for f in os.listdir(directory) if f.endswith(".h5")]
    case_ids = list(set(get_case_id(f) for f in files))
    return case_ids

def sample_cases(case_ids, percentage=0.1):
    random.shuffle(case_ids)
    sample_size = int(len(case_ids) * percentage)
    return case_ids[:sample_size]

train_dir = '/content/drive/MyDrive/Kelly/RSUU2Net/training'
val_dir   = '/content/drive/MyDrive/Kelly/RSUU2Net/validation'
test_dir  = '/content/drive/MyDrive/Kelly/RSUU2Net/testing'

train_ids = get_unique_cases(train_dir)
val_ids   = get_unique_cases(val_dir)
test_ids  = get_unique_cases(test_dir)

# jumlah_data = [len(train_sample), len(val_sample), len(test_sample)]

# num_cases_train, train_ids = count_unique_cases(train_dir)
# num_cases_val, val_ids     = count_unique_cases(val_dir)
# num_cases_test, test_ids   = count_unique_cases(test_dir)

train_sample = sample_cases(train_ids, 0.1)
val_sample   = sample_cases(val_ids, 0.1)
test_sample  = sample_cases(test_ids, 0.1)
jumlah_data = [len(train_sample), len(val_sample), len(test_sample)]

print("Training cases\t\t:", len(train_sample))
print("Validation cases\t:", len(val_sample))
print("Testing cases\t\t:", len(test_sample))
print("==========================")
print("Total cases\t\t\t:", sum(jumlah_data), "\n")

labels = ['Training', 'Validation', 'Testing']

plt.figure(figsize=(8,6))
plt.bar(labels, jumlah_data)
plt.xlabel('Subset Data')
plt.ylabel('Jumlah Kasus')
plt.title('Jumlah Kasus')
plt.show()
# Out:
# Training cases		: 87
# Validation cases	: 18
# Testing cases		: 18
# ==========================
# Total cases			: 123

# %%
print(f'Data training\t\t: {len(train_sample)}')
print(f'Data validation\t\t: {len(val_sample)}')
print(f'Data testing\t\t: {len(test_sample)} \n')

jumlah_data = [len(train_sample), len(val_sample), len(test_sample)]
# jumlah_data = [num_cases_train, num_cases_val, num_cases_test]
labels = ['Training', 'Validation', 'Testing']

# persentase_data = [num / sub_volume * 100 for num in jumlah_data]
total = sum(jumlah_data)
persentase_data = [(num / total) * 100 for num in jumlah_data]
# persentase_data = [num / sub_volume * 100 for num in jumlah_data]

plt.figure(figsize=(8, 6))
colors = ['gold', 'lightblue', 'lightgreen']
plt.pie(persentase_data, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Sebaran Pembagian Data', pad=30)
plt.axis('equal')
plt.show()
# Out:
# Data training		: 87
# Data validation		: 18
# Data testing		: 18

# %% [markdown]
# ##### Generator

# %%
# import h5py
# import numpy as np
# class VolumeDataGenerator(tf.keras.utils.Sequence):
#     def __init__(self,
#                  sample_list,
#                  base_dir,
#                  batch_size=1,
#                  shuffle=True,
#                  dim=(160, 160, 16),
#                  num_channels=4,
#                  num_classes=3,
#                  verbose=1,
#                  seed=42, **kwargs):
#         super().__init__(**kwargs)

#         self.batch_size = batch_size
#         self.shuffle = shuffle
#         self.base_dir = base_dir
#         self.dim = dim
#         self.num_channels = num_channels
#         self.num_classes = num_classes
#         self.verbose = verbose
#         self.seed = seed
#         self.sample_list = sample_list
#         self.on_epoch_end()

#     def on_epoch_end(self):
#         self.indexes = np.arange(len(self.sample_list))
#         if self.shuffle == True:
#             np.random.seed(self.seed)
#             np.random.shuffle(self.indexes)

#     def __len__(self):
#         return int(np.floor(len(self.sample_list) / self.batch_size))

#     def __data_generation(self, list_IDs_temp):
#         X = np.zeros((self.batch_size, self.num_channels, *self.dim),
#                      dtype=np.float32)
#         y = np.zeros((self.batch_size, self.num_classes, *self.dim),
#                      dtype=np.float32)

#         for i, ID in enumerate(list_IDs_temp):
#             if self.verbose == 1:
#                 print("Training on: %s" % self.base_dir + ID)
#             with h5py.File(self.base_dir + ID, 'r') as f:
#                 X[i] = np.array(f.get("x"))
#                 y[i] = np.array(f.get("y"))
#         return X, y

#     def __getitem__(self, index):
#         indexes = self.indexes[
#                   index * self.batch_size: (index + 1) * self.batch_size]
#         sample_list_temp = [self.sample_list[k] for k in indexes]
#         X, y = self.__data_generation(sample_list_temp)

#         return X, y

# %%
def load_h5_file(path, num_channels=4, num_classes=3, dim=(160,160,16)):
    def _py_load(path_bytes):
        # Ensure we get a proper string path
        if isinstance(path_bytes, (np.ndarray, np.generic)):
            path_str = path_bytes.item().decode("utf-8") if isinstance(path_bytes.item(), (bytes, bytearray)) else str(path_bytes.item())
        elif isinstance(path_bytes, (bytes, bytearray)):
            path_str = path_bytes.decode("utf-8")
        else:
            path_str = str(path_bytes)

        with h5py.File(path_str, "r") as f:
            x = np.array(f["x"], dtype=np.float32)
            y = np.array(f["y"], dtype=np.float32)
        return x, y

    x, y = tf.numpy_function(
        _py_load, [path], [tf.float32, tf.float32]
    )
    x.set_shape((num_channels, *dim))
    y.set_shape((num_classes, *dim))
    return x, y

# %%
# def build_dataset(file_list, base_dir, batch_size=2, shuffle=True):
#     paths = [os.path.join(base_dir, f) for f in file_list]
#     ds = tf.data.Dataset.from_tensor_slices(paths)

#     if shuffle:
#         ds = ds.shuffle(buffer_size=len(paths), reshuffle_each_iteration=True)

#     ds = ds.map(
#         lambda path: load_h5_file(path),
#         num_parallel_calls=tf.data.AUTOTUNE
#     )

#     ds = ds.batch(batch_size)
#     ds = ds.prefetch(tf.data.AUTOTUNE)
#     return ds

# %%
# tes_dir = "/content/drive/MyDrive/Kelly/RSUU2Net"
# with open(tes_dir + "/configurasi.json") as json_file:
#     config = json.load(json_file)

# train_ds = build_dataset(config["training"], os.path.join(tes_dir, "training"), batch_size=2)
# val_ds   = build_dataset(config["validation"], os.path.join(tes_dir, "validation"), batch_size=2, shuffle=False)
# test_ds  = build_dataset(config["testing"], os.path.join(tes_dir, "testing"), batch_size=2, shuffle=False)

# %%
# tes_dir = "/content/drive/MyDrive/Kelly/RSUU2Net"
# with open(tes_dir + "/configurasi.json") as json_file:
#   config = json.load(json_file)

# %%
# train_generator = VolumeDataGenerator(config["training"], "/content/drive/MyDrive/Kelly/RSUU2Net/training/", batch_size=2, dim = (160,160,16), verbose=2)
# valid_generator = VolumeDataGenerator(config["validation"], "/content/drive/MyDrive/Kelly/RSUU2Net/validation/", batch_size=2, dim = (160,160,16), verbose=2)
# test_generator = VolumeDataGenerator(config["testing"], "/content/drive/MyDrive/Kelly/RSUU2Net/testing/", batch_size=2, dim = (160,160,16), verbose=2)

# %%
def build_dataset(file_list, batch_size=2, shuffle=True):
    ds = tf.data.Dataset.from_tensor_slices(file_list)

    if shuffle:
        ds = ds.shuffle(buffer_size=len(file_list))

    ds = ds.map(
        lambda path: load_h5_file(path),
        num_parallel_calls=tf.data.AUTOTUNE
    )

    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# %%
def filter_files_by_case(directory, selected_cases):
    files = os.listdir(directory)
    filtered = [
        os.path.join(directory, f)
        for f in files
        if f.endswith(".h5") and get_case_id(f) in selected_cases
    ]
    return filtered

# %%
train_files = filter_files_by_case(train_dir, train_sample)
val_files   = filter_files_by_case(val_dir, val_sample)
test_files  = filter_files_by_case(test_dir, test_sample)

# %%
tes_dir = "/content/drive/MyDrive/Kelly/RSUU2Net"
with open(tes_dir + "/configurasi.json") as json_file:
    config = json.load(json_file)

# %%
train_ds = build_dataset(train_files, batch_size=2, shuffle=True)
val_ds   = build_dataset(val_files, batch_size=2, shuffle=False)
test_ds  = build_dataset(test_files, batch_size=2, shuffle=False)

# %%
print("Train files:", len(train_files))
print("Val files:", len(val_files))
# Out:
# Train files: 624
# Val files: 110

# %% [markdown]
# ### Eksplorasi Preprocessed Data

# %% [markdown]
# ## Desain Arsitektur dan Training Model

# %% [markdown]
# ### Loss Function and Metrics

# %%
# from tensorflow.keras import backend as K
# import numpy as np

# def soft_dice_loss(y_true, y_pred, axis=(1, 2, 3),
#                    epsilon=0.00001):
#     dice_numerator = 2 * K.sum(y_true * y_pred , axis= axis) + epsilon
#     dice_denominator = K.sum(y_true ** 2, axis= axis) + K.sum(y_pred ** 2 , axis = axis) + epsilon
#     dice_loss = 1 - K.mean(dice_numerator / dice_denominator)
#     return dice_loss

# # def focal_dice_loss(y_true, y_pred, gamma=2, alpha=0.5, axis=(1, 2, 3), epsilon=1e-5):
# #     dice_numerator = 2 * K.sum(y_true * y_pred, axis=axis) + epsilon
# #     dice_denominator = K.sum(y_true ** 2, axis=axis) + K.sum(y_pred ** 2, axis=axis) + epsilon
# #     dice_coefficient = dice_numerator / dice_denominator
# #     pt = (dice_numerator + epsilon) / (dice_denominator + epsilon)
# #     focal_loss = -alpha * (1 - pt)**gamma * K.log(pt)
# #     return K.mean(focal_loss + (1 - dice_coefficient))

# def dice_coefficient(y_true, y_pred, axis=(1, 2, 3), epsilon=0.00001):
#     dice_numerator = 2 * K.sum(y_true * y_pred , axis = axis) + epsilon
#     dice_denominator = K.sum(y_true, axis = axis ) + K.sum(y_pred, axis = axis) + epsilon
#     dice_coefficient = K.mean(dice_numerator/dice_denominator)
#     return dice_coefficient

# def mean_iou(y_true, y_pred, axis=(1, 2, 3), epsilon=0.00001):
#     intersection = K.sum(y_true * y_pred, axis=axis)
#     union = K.sum(y_true, axis=axis) + K.sum(y_pred, axis=axis) - intersection + epsilon
#     iou = (intersection + epsilon) / (union + epsilon)
#     iou_mean = K.mean(iou)
#     return iou_mean

# %%
from tensorflow.keras import backend as K

def soft_dice_loss(y_true, y_pred, epsilon=1e-5):
    # sum over spatial dims only
    axis = (2, 3, 4)

    numerator = 2.0 * K.sum(y_true * y_pred, axis=axis) + epsilon
    denominator = K.sum(y_true, axis=axis) + K.sum(y_pred, axis=axis) + epsilon

    dice_per_class = numerator / denominator
    return 1.0 - K.mean(dice_per_class)


def dice_coefficient(y_true, y_pred, epsilon=1e-5):
    axis = (2, 3, 4)

    numerator = 2.0 * K.sum(y_true * y_pred, axis=axis) + epsilon
    denominator = K.sum(y_true, axis=axis) + K.sum(y_pred, axis=axis) + epsilon

    dice_per_class = numerator / denominator
    return K.mean(dice_per_class)


def mean_iou(y_true, y_pred, epsilon=1e-5):
    axis = (2, 3, 4)

    intersection = K.sum(y_true * y_pred, axis=axis)
    union = K.sum(y_true + y_pred, axis=axis) - intersection + epsilon

    iou_per_class = (intersection + epsilon) / union
    return K.mean(iou_per_class)

# %% [markdown]
# ### UNet Architecture

# %%
from tensorflow.keras.layers import Input, Activation, Conv3D, Conv3DTranspose, MaxPooling3D, UpSampling3D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
tf.keras.backend.set_image_data_format('channels_first')

def create_convolution_block(input_layer, n_filters, batch_normalization=False,
                             kernel=(3, 3, 3), activation=None,
                             padding='same', strides=(1, 1, 1),
                             instance_normalization=False):

    layer = Conv3D(n_filters, kernel, padding=padding, strides=strides)(input_layer)
    if activation is None:
        return Activation('relu')(layer)
    else:
        return activation()(layer)

def get_up_convolution(n_filters, pool_size, kernel_size=(2, 2, 2),
                       strides=(2, 2, 2),
                       deconvolution=False):
    if deconvolution:
        return Conv3DTranspose(filters=n_filters, kernel_size=kernel_size, strides=strides)
    else:
        return UpSampling3D(size=pool_size)

def unet_model_3d(loss_function, input_shape=(4, 160, 160, 16),
                  pool_size=(2, 2, 2), n_labels=3,
                  initial_learning_rate=0.00001,
                  deconvolution=False, depth=4, n_base_filters=32,
                  include_label_wise_dice_coefficients=False, metrics=[],
                  batch_normalization=False, activation_name="sigmoid"):

    inputs = Input(input_shape)
    current_layer = inputs
    levels = list()

    for layer_depth in range(depth):
        layer1 = create_convolution_block(input_layer=current_layer,
                                          n_filters=n_base_filters * (2 ** layer_depth),
                                          batch_normalization=batch_normalization)
        layer2 = create_convolution_block(input_layer=layer1,
                                          n_filters=n_base_filters * (2 ** layer_depth) * 2,
                                          batch_normalization=batch_normalization)
        if layer_depth < depth - 1:
            current_layer = MaxPooling3D(pool_size=pool_size)(layer2)
            levels.append([layer1, layer2, current_layer])
        else:
            current_layer = layer2
            levels.append([layer1, layer2])

    for layer_depth in range(depth - 2, -1, -1):
        up_convolution = get_up_convolution(pool_size=pool_size,
                                            deconvolution=deconvolution,
                                            n_filters=current_layer.shape[1])(
            current_layer)
        concat = concatenate([up_convolution, levels[layer_depth][1]], axis=1)
        current_layer = create_convolution_block(
            n_filters=levels[layer_depth][1].shape[1],
            input_layer=concat, batch_normalization=batch_normalization)
        current_layer = create_convolution_block(
            n_filters=levels[layer_depth][1].shape[1],
            input_layer=current_layer,
            batch_normalization=batch_normalization)

    final_convolution = Conv3D(n_labels, (1, 1, 1))(current_layer)
    act = Activation(activation_name)(final_convolution)
    model = Model(inputs=inputs, outputs=act)

    if not isinstance(metrics, list):
        metrics = [metrics]

    model.compile(optimizer=Adam(learning_rate=initial_learning_rate), loss=loss_function, metrics=metrics)
    return model

# %%
model = unet_model_3d(loss_function=soft_dice_loss, metrics=[mean_iou, dice_coefficient])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 4, 160,    │          0 │ -                 │
# │ (InputLayer)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 32, 160,   │      3,488 │ input_layer[0][0] │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 160,   │          0 │ conv3d[0][0]      │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 64, 160,   │     55,360 │ activation[0][0]  │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 64, 160,   │          0 │ conv3d_1[0][0]    │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d       │ (None, 64, 80,    │          0 │ activation_1[0][… │
# │ (MaxPooling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_2 (Conv3D)   │ (None, 64, 80,    │    110,656 │ max_pooling3d[0]… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 80,    │          0 │ conv3d_2[0][0]    │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 128, 80,   │    221,312 │ activation_2[0][… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 80,   │          0 │ conv3d_3[0][0]    │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_1     │ (None, 128, 40,   │          0 │ activation_3[0][… │
# │ (MaxPooling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_4 (Conv3D)   │ (None, 128, 40,   │    442,496 │ max_pooling3d_1[… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128, 40,   │          0 │ conv3d_4[0][0]    │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_5 (Conv3D)   │ (None, 256, 40,   │    884,992 │ activation_4[0][… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 256, 40,   │          0 │ conv3d_5[0][0]    │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_2     │ (None, 256, 20,   │          0 │ activation_5[0][… │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_6 (Conv3D)   │ (None, 256, 20,   │  1,769,728 │ max_pooling3d_2[… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 256, 20,   │          0 │ conv3d_6[0][0]    │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_7 (Conv3D)   │ (None, 512, 20,   │  3,539,456 │ activation_6[0][… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 512, 20,   │          0 │ conv3d_7[0][0]    │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d       │ (None, 512, 40,   │          0 │ activation_7[0][… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 768, 40,   │          0 │ up_sampling3d[0]… │
# │ (Concatenate)       │ 40, 4)            │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_8 (Conv3D)   │ (None, 256, 40,   │  5,308,672 │ concatenate[0][0] │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 256, 40,   │          0 │ conv3d_8[0][0]    │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_9 (Conv3D)   │ (None, 256, 40,   │  1,769,728 │ activation_8[0][… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 256, 40,   │          0 │ conv3d_9[0][0]    │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_1     │ (None, 256, 80,   │          0 │ activation_9[0][… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 384, 80,   │          0 │ up_sampling3d_1[… │
# │ (Concatenate)       │ 80, 8)            │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_10 (Conv3D)  │ (None, 128, 80,   │  1,327,232 │ concatenate_1[0]… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 128, 80,   │          0 │ conv3d_10[0][0]   │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_11 (Conv3D)  │ (None, 128, 80,   │    442,496 │ activation_10[0]… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 128, 80,   │          0 │ conv3d_11[0][0]   │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_2     │ (None, 128, 160,  │          0 │ activation_11[0]… │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 192, 160,  │          0 │ up_sampling3d_2[… │
# │ (Concatenate)       │ 160, 16)          │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_12 (Conv3D)  │ (None, 64, 160,   │    331,840 │ concatenate_2[0]… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 160,   │          0 │ conv3d_12[0][0]   │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_13 (Conv3D)  │ (None, 64, 160,   │    110,656 │ activation_12[0]… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 160,   │          0 │ conv3d_13[0][0]   │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_14 (Conv3D)  │ (None, 3, 160,    │        195 │ activation_13[0]… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 3, 160,    │          0 │ conv3d_14[0][0]   │
# │ (Activation)        │ 160, 16)          │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 16,318,307 (62.25 MB)
#  Trainable params: 16,318,307 (62.25 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(train_generator,
        epochs=35,
        use_multiprocessing=True,
        validation_data=valid_generator
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5687/1592557118.py in <cell line: 0>()
# ----> 1 model.fit(train_generator,
#       2         epochs=35,
#       3         use_multiprocessing=True,
#       4         validation_data=valid_generator
#       5         )
#
# NameError: name 'train_generator' is not defined

# %%
# model.save_weights('/content/drive/MyDrive/Projek_Skripsi_RSU_U^2_Net_3D/3DSegmentationRSU_U^2Net++/model/weight_model_U-Net.hdf5')
# model.load_weights('/content/drive/MyDrive/Projek_Skripsi_RSU_U^2_Net_3D/3DSegmentationRSU_U^2Net++/model/weight_model_U-Net.hdf5')

# %% [markdown]
# ### Feature Channel Attention RSU U^2 Net+ Architecture (Proposed Architecture)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv3D, BatchNormalization, Activation, MaxPooling3D, UpSampling3D, Concatenate, Add, GlobalAveragePooling3D, Dense, Reshape, Multiply, Lambda
tf.keras.backend.set_image_data_format('channels_first')

def conv_block(inputs, out_ch, rate=1):
    x = Conv3D(out_ch, 3, padding="same", dilation_rate=1)(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def FeatureChannelAttention(x, g, inter_channels):
    # 1x1 conv
    theta_x = Conv3D(inter_channels, 1, padding="same")(x)
    phi_g   = Conv3D(inter_channels, 1, padding="same")(g)

    # combine
    f = Add()([theta_x, phi_g])
    f = Activation("relu")(f)

    # attention score
    psi = Conv3D(1, 1, padding="same")(f)
    psi = Activation("sigmoid")(psi)

    # apply attention
    x_att = Multiply()([x, psi])

    # residual
    out = Add()([x, x_att])

    return out

def RSU_L(inputs, out_ch, int_ch, num_layers, rate=2):
    x = conv_block(inputs, out_ch)
    init_feats = x

    skip = []
    x = conv_block(x, int_ch)
    skip.append(x)

    for i in range(num_layers - 2):
        x = MaxPooling3D((2, 2, 2))(x)
        x = conv_block(x, int_ch)
        skip.append(x)

    x = conv_block(x, int_ch, rate=rate)

    skip.reverse()

    x = Concatenate(axis=1)([x, skip[0]])
    x = conv_block(x, int_ch)

    for i in range(num_layers - 3):
        x = UpSampling3D(size=(2, 2, 2))(x)
        x_concat = Concatenate(axis=1)([skip[i + 1], UpSampling3D(size=(2, 2, 2))(skip[i])])
        x = Concatenate(axis=1)([x, x_concat])
        x = conv_block(x, int_ch)

    x = UpSampling3D(size=(2, 2, 2))(x)
    x = Concatenate(axis=1)([x, skip[-1]])
    x = conv_block(x, out_ch)

    x = Add()([x, init_feats])
    return x

def RSU_4F(inputs, out_ch, int_ch):
    x0 = conv_block(inputs, out_ch, rate=1)

    x1 = conv_block(x0, int_ch, rate=1)
    x2 = conv_block(x1, int_ch, rate=2)
    x3 = conv_block(x2, int_ch, rate=4)

    x4 = conv_block(x3, int_ch, rate=8)

    x = Concatenate(axis=1)([x4, x3])
    x = conv_block(x, int_ch, rate=4)

    x = Concatenate(axis=1)([x, x2])
    x = conv_block(x, int_ch, rate=2)

    x = Concatenate(axis=1)([x, x1])
    x = conv_block(x, out_ch, rate=1)

    x = Add()([x, x0])
    return x

def u2net(input_shape, out_ch, int_ch, num_classes=3):
    inputs = Input(input_shape)
    s0 = inputs

    s1 = RSU_L(s0, out_ch[0], int_ch[0], 6)
    p1 = MaxPooling3D((2, 2, 2))(s1)

    s2 = RSU_L(p1, out_ch[1], int_ch[1], 5)
    p2 = MaxPooling3D((2, 2, 2))(s2)

    s3 = RSU_L(p2, out_ch[2], int_ch[2], 4)
    p3 = MaxPooling3D((2, 2, 2))(s3)

    s4 = RSU_4F(p3, out_ch[3], int_ch[3])
    p4 = MaxPooling3D((2, 2, 2))(s4)

    b1 = RSU_4F(p4, out_ch[4], int_ch[4])
    b2 = UpSampling3D(size=(2, 2, 2))(b1)

    s4_feat = FeatureChannelAttention(s4, b2, inter_channels=out_ch[3] // 2)
    d1 = Concatenate(axis=1)([b2, s4_feat])
    d1 = RSU_4F(d1, out_ch[5], int_ch[5])
    u1 = UpSampling3D(size=(2, 2, 2))(d1)

    s3_feat = FeatureChannelAttention(s3, u1, inter_channels=out_ch[2] // 2)
    d2 = Concatenate(axis=1)([u1, s3_feat])
    d2 = RSU_L(d2, out_ch[6], int_ch[6], 4)
    u2 = UpSampling3D(size=(2, 2, 2))(d2)

    s2_feat = FeatureChannelAttention(s2, u2, inter_channels=out_ch[1] // 2)
    d3 = Concatenate(axis=1)([u2, s2_feat])
    d3 = RSU_L(d3, out_ch[7], int_ch[7], 5)
    u3 = UpSampling3D(size=(2, 2, 2))(d3)

    s1_feat = FeatureChannelAttention(s1, u3, inter_channels=out_ch[0] // 2)
    d4 = Concatenate(axis=1)([u3, s1_feat])
    d4 = RSU_L(d4, out_ch[8], int_ch[8], 6)

    y1 = Conv3D(num_classes, 3, padding="same")(d4)

    y2 = Conv3D(num_classes, 3, padding="same")(d3)
    y2 = UpSampling3D(size=(2, 2, 2))(y2)

    y3 = Conv3D(num_classes, 3, padding="same")(d2)
    y3 = UpSampling3D(size=(4, 4, 4))(y3)

    y4 = Conv3D(num_classes, 3, padding="same")(d1)
    y4 = UpSampling3D(size=(8, 8, 8))(y4)

    y5 = Conv3D(num_classes, 3, padding="same")(b1)
    y5 = UpSampling3D(size=(16, 16, 16))(y5)

    y6 = Concatenate(axis=1)([y1, y2, y3, y4, y5])
    y6 = Conv3D(num_classes, 1, padding="same")(y6)
    y6 = Activation("sigmoid")(y6)

    model = tf.keras.models.Model(inputs, outputs=y6)
    return model

def build_u2net(input_shape, num_classes=3):
    out_ch = [32, 64, 128, 256, 512, 256, 128, 64, 32]
    int_ch = [32, 32, 64, 128, 256, 128, 64, 32, 32]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

# model = build_u2net((4, 160, 160, 16))
# model.summary()

# %%
# from tensorflow.keras.optimizers import Adamax
# from tensorflow.keras import callbacks
# model.compile(optimizer=Adamax(learning_rate=0.001), loss=soft_dice_loss, metrics=[mean_iou, dice_coefficient])

# %%
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

model = build_u2net(
    input_shape=(4, 160, 160, 16),
    num_classes=3
)

model.compile(
    optimizer= AdamW(learning_rate=0.000001),
    loss=soft_dice_loss,
    metrics=[mean_iou, dice_coefficient]
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 4, 160,    │          0 │ -                 │
# │ (InputLayer)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 32, 160,   │      3,488 │ input_layer[0][0] │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 160,   │         64 │ conv3d[0][0]      │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 32, 160,   │     27,680 │ activation[0][0]  │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 160,   │         64 │ conv3d_1[0][0]    │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d       │ (None, 32, 80,    │          0 │ activation_1[0][… │
# │ (MaxPooling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_2 (Conv3D)   │ (None, 32, 80,    │     27,680 │ max_pooling3d[0]… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_2[0][0]    │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_1     │ (None, 32, 40,    │          0 │ activation_2[0][… │
# │ (MaxPooling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 32, 40,    │     27,680 │ max_pooling3d_1[… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_3[0][0]    │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_2     │ (None, 32, 20,    │          0 │ activation_3[0][… │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_4 (Conv3D)   │ (None, 32, 20,    │     27,680 │ max_pooling3d_2[… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_4[0][0]    │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_3     │ (None, 32, 10,    │          0 │ activation_4[0][… │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_5 (Conv3D)   │ (None, 32, 10,    │     27,680 │ max_pooling3d_3[… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_5[0][0]    │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_6 (Conv3D)   │ (None, 32, 10,    │     27,680 │ activation_5[0][… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_6[0][0]    │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 10,    │          0 │ activation_6[0][… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_7 (Conv3D)   │ (None, 32, 10,    │     55,328 │ concatenate[0][0] │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_7[0][0]    │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_1     │ (None, 32, 20,    │          0 │ activation_5[0][… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d       │ (None, 32, 20,    │          0 │ activation_7[0][… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 20,    │          0 │ activation_4[0][… │
# │ (Concatenate)       │ 20, 2)            │            │ up_sampling3d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 96, 20,    │          0 │ up_sampling3d[0]… │
# │ (Concatenate)       │ 20, 2)            │            │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_8 (Conv3D)   │ (None, 32, 20,    │     82,976 │ concatenate_2[0]… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_8[0][0]    │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_3     │ (None, 32, 40,    │          0 │ activation_4[0][… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_2     │ (None, 32, 40,    │          0 │ activation_8[0][… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 40,    │          0 │ activation_3[0][… │
# │ (Concatenate)       │ 40, 4)            │            │ up_sampling3d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 96, 40,    │          0 │ up_sampling3d_2[… │
# │ (Concatenate)       │ 40, 4)            │            │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_9 (Conv3D)   │ (None, 32, 40,    │     82,976 │ concatenate_4[0]… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_9[0][0]    │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_5     │ (None, 32, 80,    │          0 │ activation_3[0][… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_4     │ (None, 32, 80,    │          0 │ activation_9[0][… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 80,    │          0 │ activation_2[0][… │
# │ (Concatenate)       │ 80, 8)            │            │ up_sampling3d_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 96, 80,    │          0 │ up_sampling3d_4[… │
# │ (Concatenate)       │ 80, 8)            │            │ concatenate_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_10 (Conv3D)  │ (None, 32, 80,    │     82,976 │ concatenate_6[0]… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_10[0][0]   │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_6     │ (None, 32, 160,   │          0 │ activation_10[0]… │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 64, 160,   │          0 │ up_sampling3d_6[… │
# │ (Concatenate)       │ 160, 16)          │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_11 (Conv3D)  │ (None, 32, 160,   │     55,328 │ concatenate_7[0]… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 160,   │         64 │ conv3d_11[0][0]   │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 160,   │          0 │ activation_11[0]… │
# │                     │ 160, 16)          │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_4     │ (None, 32, 80,    │          0 │ add[0][0]         │
# │ (MaxPooling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_12 (Conv3D)  │ (None, 64, 80,    │     55,360 │ max_pooling3d_4[… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 80,    │         32 │ conv3d_12[0][0]   │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_13 (Conv3D)  │ (None, 32, 80,    │     55,328 │ activation_12[0]… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_13[0][0]   │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_5     │ (None, 32, 40,    │          0 │ activation_13[0]… │
# │ (MaxPooling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_14 (Conv3D)  │ (None, 32, 40,    │     27,680 │ max_pooling3d_5[… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_14[0][0]   │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_6     │ (None, 32, 20,    │          0 │ activation_14[0]… │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_15 (Conv3D)  │ (None, 32, 20,    │     27,680 │ max_pooling3d_6[… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_15[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_7     │ (None, 32, 10,    │          0 │ activation_15[0]… │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_16 (Conv3D)  │ (None, 32, 10,    │     27,680 │ max_pooling3d_7[… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_16[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_17 (Conv3D)  │ (None, 32, 10,    │     27,680 │ activation_16[0]… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_17[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 64, 10,    │          0 │ activation_17[0]… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_18 (Conv3D)  │ (None, 32, 10,    │     55,328 │ concatenate_8[0]… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_18[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_8     │ (None, 32, 20,    │          0 │ activation_16[0]… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_7     │ (None, 32, 20,    │          0 │ activation_18[0]… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 64, 20,    │          0 │ activation_15[0]… │
# │ (Concatenate)       │ 20, 2)            │            │ up_sampling3d_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 96, 20,    │          0 │ up_sampling3d_7[… │
# │ (Concatenate)       │ 20, 2)            │            │ concatenate_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_19 (Conv3D)  │ (None, 32, 20,    │     82,976 │ concatenate_10[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_19[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_10    │ (None, 32, 40,    │          0 │ activation_15[0]… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_9     │ (None, 32, 40,    │          0 │ activation_19[0]… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 64, 40,    │          0 │ activation_14[0]… │
# │ (Concatenate)       │ 40, 4)            │            │ up_sampling3d_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 96, 40,    │          0 │ up_sampling3d_9[… │
# │ (Concatenate)       │ 40, 4)            │            │ concatenate_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_20 (Conv3D)  │ (None, 32, 40,    │     82,976 │ concatenate_12[0… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_20[0][0]   │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_11    │ (None, 32, 80,    │          0 │ activation_20[0]… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 64, 80,    │          0 │ up_sampling3d_11… │
# │ (Concatenate)       │ 80, 8)            │            │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_21 (Conv3D)  │ (None, 64, 80,    │    110,656 │ concatenate_13[0… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 80,    │         32 │ conv3d_21[0][0]   │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 64, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 80,    │          0 │ activation_21[0]… │
# │                     │ 80, 8)            │            │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_8     │ (None, 64, 40,    │          0 │ add_1[0][0]       │
# │ (MaxPooling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_22 (Conv3D)  │ (None, 128, 40,   │    221,312 │ max_pooling3d_8[… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 40,   │         16 │ conv3d_22[0][0]   │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 128, 40,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_23 (Conv3D)  │ (None, 64, 40,    │    221,248 │ activation_22[0]… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 40,    │         16 │ conv3d_23[0][0]   │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 64, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_9     │ (None, 64, 20,    │          0 │ activation_23[0]… │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_24 (Conv3D)  │ (None, 64, 20,    │    110,656 │ max_pooling3d_9[… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 20,    │          8 │ conv3d_24[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 64, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_10    │ (None, 64, 10,    │          0 │ activation_24[0]… │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_25 (Conv3D)  │ (None, 64, 10,    │    110,656 │ max_pooling3d_10… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 10,    │          4 │ conv3d_25[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 64, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_26 (Conv3D)  │ (None, 64, 10,    │    110,656 │ activation_25[0]… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 10,    │          4 │ conv3d_26[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 64, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 128, 10,   │          0 │ activation_26[0]… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_27 (Conv3D)  │ (None, 64, 10,    │    221,248 │ concatenate_14[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 10,    │          4 │ conv3d_27[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 64, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_13    │ (None, 64, 20,    │          0 │ activation_25[0]… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_12    │ (None, 64, 20,    │          0 │ activation_27[0]… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 128, 20,   │          0 │ activation_24[0]… │
# │ (Concatenate)       │ 20, 2)            │            │ up_sampling3d_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 192, 20,   │          0 │ up_sampling3d_12… │
# │ (Concatenate)       │ 20, 2)            │            │ concatenate_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_28 (Conv3D)  │ (None, 64, 20,    │    331,840 │ concatenate_16[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 20,    │          8 │ conv3d_28[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 64, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_14    │ (None, 64, 40,    │          0 │ activation_28[0]… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 128, 40,   │          0 │ up_sampling3d_14… │
# │ (Concatenate)       │ 40, 4)            │            │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_29 (Conv3D)  │ (None, 128, 40,   │    442,496 │ concatenate_17[0… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 40,   │         16 │ conv3d_29[0][0]   │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 128, 40,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128, 40,   │          0 │ activation_29[0]… │
# │                     │ 40, 4)            │            │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_11    │ (None, 128, 20,   │          0 │ add_2[0][0]       │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_30 (Conv3D)  │ (None, 256, 20,   │    884,992 │ max_pooling3d_11… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 20,   │          8 │ conv3d_30[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 256, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_31 (Conv3D)  │ (None, 128, 20,   │    884,864 │ activation_30[0]… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_31[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_32 (Conv3D)  │ (None, 128, 20,   │    442,496 │ activation_31[0]… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_32[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_33 (Conv3D)  │ (None, 128, 20,   │    442,496 │ activation_32[0]… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_33[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_34 (Conv3D)  │ (None, 128, 20,   │    442,496 │ activation_33[0]… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_34[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 256, 20,   │          0 │ activation_34[0]… │
# │ (Concatenate)       │ 20, 2)            │            │ activation_33[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_35 (Conv3D)  │ (None, 128, 20,   │    884,864 │ concatenate_18[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_35[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 256, 20,   │          0 │ activation_35[0]… │
# │ (Concatenate)       │ 20, 2)            │            │ activation_32[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_36 (Conv3D)  │ (None, 128, 20,   │    884,864 │ concatenate_19[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_36[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 256, 20,   │          0 │ activation_36[0]… │
# │ (Concatenate)       │ 20, 2)            │            │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_37 (Conv3D)  │ (None, 256, 20,   │  1,769,728 │ concatenate_20[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 20,   │          8 │ conv3d_37[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 256, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 256, 20,   │          0 │ activation_37[0]… │
# │                     │ 20, 2)            │            │ activation_30[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_12    │ (None, 256, 10,   │          0 │ add_3[0][0]       │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_38 (Conv3D)  │ (None, 512, 10,   │  3,539,456 │ max_pooling3d_12… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 10,   │          4 │ conv3d_38[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 512, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_39 (Conv3D)  │ (None, 256, 10,   │  3,539,200 │ activation_38[0]… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_39[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_40 (Conv3D)  │ (None, 256, 10,   │  1,769,728 │ activation_39[0]… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_40[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_41 (Conv3D)  │ (None, 256, 10,   │  1,769,728 │ activation_40[0]… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_41[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_42 (Conv3D)  │ (None, 256, 10,   │  1,769,728 │ activation_41[0]… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_42[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 512, 10,   │          0 │ activation_42[0]… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_41[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_43 (Conv3D)  │ (None, 256, 10,   │  3,539,200 │ concatenate_21[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_43[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 512, 10,   │          0 │ activation_43[0]… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_40[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_44 (Conv3D)  │ (None, 256, 10,   │  3,539,200 │ concatenate_22[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_44[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 512, 10,   │          0 │ activation_44[0]… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_45 (Conv3D)  │ (None, 512, 10,   │  7,078,400 │ concatenate_23[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 10,   │          4 │ conv3d_45[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 512, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 512, 10,   │          0 │ activation_45[0]… │
# │                     │ 10, 1)            │            │ activation_38[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_15    │ (None, 512, 20,   │          0 │ add_4[0][0]       │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_46 (Conv3D)  │ (None, 128, 20,   │     32,896 │ add_3[0][0]       │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_47 (Conv3D)  │ (None, 128, 20,   │     65,664 │ up_sampling3d_15… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 128, 20,   │          0 │ conv3d_46[0][0],  │
# │                     │ 20, 2)            │            │ conv3d_47[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 128, 20,   │          0 │ add_5[0][0]       │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_48 (Conv3D)  │ (None, 1, 20, 20, │        129 │ activation_46[0]… │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 1, 20, 20, │          0 │ conv3d_48[0][0]   │
# │ (Activation)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256, 20,   │          0 │ add_3[0][0],      │
# │                     │ 20, 2)            │            │ activation_47[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 256, 20,   │          0 │ add_3[0][0],      │
# │                     │ 20, 2)            │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 768, 20,   │          0 │ up_sampling3d_15… │
# │ (Concatenate)       │ 20, 2)            │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_49 (Conv3D)  │ (None, 256, 20,   │  5,308,672 │ concatenate_24[0… │
# │                     │ 20, 2)            │            │                   │
# ...
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 160,   │         64 │ conv3d_84[0][0]   │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_80       │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_85 (Conv3D)  │ (None, 32, 160,   │     27,680 │ activation_80[0]… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 160,   │         64 │ conv3d_85[0][0]   │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_81       │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_18    │ (None, 32, 80,    │          0 │ activation_81[0]… │
# │ (MaxPooling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_86 (Conv3D)  │ (None, 32, 80,    │     27,680 │ max_pooling3d_18… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_86[0][0]   │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_82       │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_19    │ (None, 32, 40,    │          0 │ activation_82[0]… │
# │ (MaxPooling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_87 (Conv3D)  │ (None, 32, 40,    │     27,680 │ max_pooling3d_19… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_87[0][0]   │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_83       │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_20    │ (None, 32, 20,    │          0 │ activation_83[0]… │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_88 (Conv3D)  │ (None, 32, 20,    │     27,680 │ max_pooling3d_20… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_88[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_84       │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_21    │ (None, 32, 10,    │          0 │ activation_84[0]… │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_89 (Conv3D)  │ (None, 32, 10,    │     27,680 │ max_pooling3d_21… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_89[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_85       │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_90 (Conv3D)  │ (None, 32, 10,    │     27,680 │ activation_85[0]… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_90[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_86       │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_41      │ (None, 64, 10,    │          0 │ activation_86[0]… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_85[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_91 (Conv3D)  │ (None, 32, 10,    │     55,328 │ concatenate_41[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_91[0][0]   │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_87       │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_28    │ (None, 32, 20,    │          0 │ activation_85[0]… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_27    │ (None, 32, 20,    │          0 │ activation_87[0]… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_42      │ (None, 64, 20,    │          0 │ activation_84[0]… │
# │ (Concatenate)       │ 20, 2)            │            │ up_sampling3d_28… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_43      │ (None, 96, 20,    │          0 │ up_sampling3d_27… │
# │ (Concatenate)       │ 20, 2)            │            │ concatenate_42[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_92 (Conv3D)  │ (None, 32, 20,    │     82,976 │ concatenate_43[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_92[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_88       │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_30    │ (None, 32, 40,    │          0 │ activation_84[0]… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_29    │ (None, 32, 40,    │          0 │ activation_88[0]… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_44      │ (None, 64, 40,    │          0 │ activation_83[0]… │
# │ (Concatenate)       │ 40, 4)            │            │ up_sampling3d_30… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_45      │ (None, 96, 40,    │          0 │ up_sampling3d_29… │
# │ (Concatenate)       │ 40, 4)            │            │ concatenate_44[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_93 (Conv3D)  │ (None, 32, 40,    │     82,976 │ concatenate_45[0… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_93[0][0]   │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_89       │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_32    │ (None, 32, 80,    │          0 │ activation_83[0]… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_31    │ (None, 32, 80,    │          0 │ activation_89[0]… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_46      │ (None, 64, 80,    │          0 │ activation_82[0]… │
# │ (Concatenate)       │ 80, 8)            │            │ up_sampling3d_32… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_47      │ (None, 96, 80,    │          0 │ up_sampling3d_31… │
# │ (Concatenate)       │ 80, 8)            │            │ concatenate_46[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_94 (Conv3D)  │ (None, 32, 80,    │     82,976 │ concatenate_47[0… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_94[0][0]   │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_90       │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_33    │ (None, 32, 160,   │          0 │ activation_90[0]… │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_48      │ (None, 64, 160,   │          0 │ up_sampling3d_33… │
# │ (Concatenate)       │ 160, 16)          │            │ activation_81[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_95 (Conv3D)  │ (None, 32, 160,   │     55,328 │ concatenate_48[0… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 160,   │         64 │ conv3d_95[0][0]   │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_91       │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 32, 160,   │          0 │ activation_91[0]… │
# │                     │ 160, 16)          │            │ activation_80[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_97 (Conv3D)  │ (None, 3, 80, 80, │      5,187 │ add_13[0][0]      │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_98 (Conv3D)  │ (None, 3, 40, 40, │     10,371 │ add_10[0][0]      │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_99 (Conv3D)  │ (None, 3, 20, 20, │     20,739 │ add_7[0][0]       │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_100 (Conv3D) │ (None, 3, 10, 10, │     41,475 │ add_4[0][0]       │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_96 (Conv3D)  │ (None, 3, 160,    │      2,595 │ add_16[0][0]      │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_34    │ (None, 3, 160,    │          0 │ conv3d_97[0][0]   │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_35    │ (None, 3, 160,    │          0 │ conv3d_98[0][0]   │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_36    │ (None, 3, 160,    │          0 │ conv3d_99[0][0]   │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_37    │ (None, 3, 160,    │          0 │ conv3d_100[0][0]  │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_49      │ (None, 15, 160,   │          0 │ conv3d_96[0][0],  │
# │ (Concatenate)       │ 160, 16)          │            │ up_sampling3d_34… │
# │                     │                   │            │ up_sampling3d_35… │
# │                     │                   │            │ up_sampling3d_36… │
# │                     │                   │            │ up_sampling3d_37… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_101 (Conv3D) │ (None, 3, 160,    │         48 │ concatenate_49[0… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_92       │ (None, 3, 160,    │          0 │ conv3d_101[0][0]  │
# │ (Activation)        │ 160, 16)          │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 51,621,979 (196.92 MB)
#  Trainable params: 51,621,351 (196.92 MB)
#  Non-trainable params: 628 (2.45 KB)

# %%
model_history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1111s 3s/step - dice_coefficient: 0.0255 - loss: 0.9746 - mean_iou: 0.0131 - val_dice_coefficient: 0.0276 - val_loss: 0.9724 - val_mean_iou: 0.0143
# Epoch 2/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - dice_coefficient: 0.0283 - loss: 0.9717 - mean_iou: 0.0146 - val_dice_coefficient: 0.0300 - val_loss: 0.9700 - val_mean_iou: 0.0156
# Epoch 3/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - dice_coefficient: 0.0303 - loss: 0.9697 - mean_iou: 0.0157 - val_dice_coefficient: 0.0316 - val_loss: 0.9684 - val_mean_iou: 0.0164
# Epoch 4/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - dice_coefficient: 0.0315 - loss: 0.9685 - mean_iou: 0.0164 - val_dice_coefficient: 0.0325 - val_loss: 0.9675 - val_mean_iou: 0.0169
# Epoch 5/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 506s 2s/step - dice_coefficient: 0.0324 - loss: 0.9677 - mean_iou: 0.0169 - val_dice_coefficient: 0.0332 - val_loss: 0.9668 - val_mean_iou: 0.0173
# Epoch 6/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - dice_coefficient: 0.0329 - loss: 0.9671 - mean_iou: 0.0171 - val_dice_coefficient: 0.0337 - val_loss: 0.9663 - val_mean_iou: 0.0176
# Epoch 7/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - dice_coefficient: 0.0333 - loss: 0.9667 - mean_iou: 0.0174 - val_dice_coefficient: 0.0340 - val_loss: 0.9660 - val_mean_iou: 0.0178
# Epoch 8/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - dice_coefficient: 0.0337 - loss: 0.9663 - mean_iou: 0.0176 - val_dice_coefficient: 0.0344 - val_loss: 0.9657 - val_mean_iou: 0.0179
# Epoch 9/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - dice_coefficient: 0.0341 - loss: 0.9659 - mean_iou: 0.0178 - val_dice_coefficient: 0.0346 - val_loss: 0.9654 - val_mean_iou: 0.0181
# Epoch 10/10
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - dice_coefficient: 0.0344 - loss: 0.9656 - mean_iou: 0.0179 - val_dice_coefficient: 0.0349 - val_loss: 0.9651 - val_mean_iou: 0.0182

# %%
import pickle

with open('/content/drive/MyDrive/Kelly/RSUU2Net/model/history_cbam_u2net.pkl', 'wb') as f:
    pickle.dump(model_history.history, f)

# %%
# model.save_weights('/content/drive/MyDrive/Kelly/RSUU2Net/model/weight_model_cbam_rsu2net.weights.h5')
# model.load_weights('/content/drive/MyDrive/Kelly/RSUU2Net/model/weight_model_cbam_rsu2net.weights.h5')
# model.save('/content/drive/MyDrive/Kelly/RSUU2Net/model/pretrained_model_cbam_rsu2net.h5')

# %%
def plot_history(history):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    metric_key = 'dice_coefficient' if 'dice_coefficient' in history.history else 'accuracy'
    plt.plot(history.history[metric_key], label=f'Train {metric_key}')
    if f'val_{metric_key}' in history.history:
        plt.plot(history.history[f'val_{metric_key}'], label=f'Val {metric_key}')
    plt.title(f'{metric_key.capitalize()} over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel(metric_key.capitalize())
    plt.legend()
    plt.grid(True)

    plt.show()

plot_history(model_history)

# %% [markdown]
# ## Evaluasi Model

# %% [markdown]
# ### Dice Ceofficient dan IoU

# %%
# Proposed Architecture
test_loss, test_iou, test_dice = model.evaluate(test_ds)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - dice_coefficient: 0.0328 - loss: 0.9674 - mean_iou: 0.0171

# %%
# # U-Net
# test_loss, test_iou, test_dice = model.evaluate(test_generator)

# %% [markdown]
# ### Recall and Specificity

# %% [markdown]
# #### 1 sub volume pada test generator

# %%
for X_sub_volume, y_sub_volume in test_ds.take(1):
    X_sub_volume = X_sub_volume.numpy()
    y_sub_volume = y_sub_volume.numpy()
    break

print("Input shape:", X_sub_volume.shape)
print("Label shape:", y_sub_volume.shape)
# Out:
# Input shape: (2, 4, 160, 160, 16)
# Label shape: (2, 3, 160, 160, 16)

# %%
print(X_sub_volume.shape)
# Out:
# (2, 4, 160, 160, 16)

# %%
satu_sub_volume_image = X_sub_volume[0]
print(satu_sub_volume_image.shape)
# Out:
# (4, 160, 160, 16)

# %%
print(y_sub_volume.shape)
# Out:
# (2, 3, 160, 160, 16)

# %%
satu_sub_volume_groundTruth = y_sub_volume[0]
print(satu_sub_volume_groundTruth.shape)
# Out:
# (3, 160, 160, 16)

# %%
X_with_batch_dimension = np.expand_dims(satu_sub_volume_image, axis=0)
data_sen_spe = model.predict(X_with_batch_dimension)
threshold = 0.5
data_sen_spe[data_sen_spe > threshold] = 1.0
data_sen_spe[data_sen_spe <= threshold] = 0.0
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step

# %%
def visualize_patch(volume, mask, slice_idx=None):
    if volume.ndim == 4:
        volume = volume[0]

    if slice_idx is None:
        slice_idx = volume.shape[-1] // 2

    img_slice = volume[:, :, slice_idx]
    mask_slice = mask[:, :, slice_idx] if mask.ndim == 3 else mask

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(img_slice, cmap="gray")
    plt.title("MRI Image")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(img_slice, cmap="gray")
    plt.imshow(mask_slice, cmap="jet", alpha=0.5)
    plt.title("Segmentation")
    plt.axis("off")

# %%
print("Sub Volume dan Mask (ground truth)")
visualize_patch(satu_sub_volume_image[0, :, :, :], satu_sub_volume_groundTruth[0])
plt.show()
print("Sub Volume dan Mask (predicton)")
visualize_patch(satu_sub_volume_image[0, :, :, :], data_sen_spe[0, 0, :, :, :])
plt.show()
# Out:
# Sub Volume dan Mask (ground truth)
# Sub Volume dan Mask (predicton)

# %%
def hitung_recall_specificity_satu_kelas(pred, label, class_num):
  class_pred = pred[class_num]
  class_label = label[class_num]
  tp = np.sum((class_pred==1) * (class_label==1))
  tn = np.sum((class_pred==0) * (class_label==0))
  fp = np.sum((class_pred==1) * (class_label==0))
  fn = np.sum((class_pred==0) * (class_label==1))
  if tp + fn == 0:
    recall = 0
  else:
      recall = tp / (tp + fn)

  if (tn + fp) == 0:
      specificity = 0
  else:
    specificity = tn / (tn + fp)
  return recall, specificity

def hitung_recall_specificity_setiap_kelas(pred, label):
  patches_matriks = pd.DataFrame(
      columns = ['Endema',
                 'Non-Enhancing Tumor',
                 'Enhancing Tumor'],
      index = ['Recall',
               'Specificity']
  )
  for i, class_name in enumerate(patches_matriks.columns):
    rec,spec = hitung_recall_specificity_satu_kelas(pred, label, i)
    patches_matriks.loc['Recall', class_name] = round(rec, 4)
    patches_matriks.loc['Specificity', class_name] = round(spec, 4)
  return patches_matriks

sens_spe = hitung_recall_specificity_setiap_kelas(data_sen_spe[0], satu_sub_volume_groundTruth)

print(sens_spe)
# Out:
#              Endema Non-Enhancing Tumor Enhancing Tumor
# Recall       0.4853              0.7078               0
# Specificity  0.4528              0.6588           0.653

# %% [markdown]
# #### semua sub volume pada test generator

# %%
def hitung_recall_specificity_satu_kelas(pred, label, class_num):
  class_pred = pred[class_num]
  class_label = label[class_num]
  tp = np.sum((class_pred==1) * (class_label==1))
  tn = np.sum((class_pred==0) * (class_label==0))
  fp = np.sum((class_pred==1) * (class_label==0))
  fn = np.sum((class_pred==0) * (class_label==1))
  if tp + fn == 0:
    recall = 0
  else:
      recall = tp / (tp + fn)

  if (tn + fp) == 0:
      specificity = 0
  else:
    specificity = tn / (tn + fp)
  return recall, specificity

def hitung_recall_specificity_setiap_kelas(pred, label):
  patches_matriks = pd.DataFrame(
      columns = ['Endema',
                 'Non-Enhancing Tumor',
                 'Enhancing Tumor'],
      index = ['Recall',
               'Specificity']
  )
  for i, class_name in enumerate(patches_matriks.columns):
    rec,spec = hitung_recall_specificity_satu_kelas(pred, label, i)
    patches_matriks.loc['Recall', class_name] = round(rec, 4)
    patches_matriks.loc['Specificity', class_name] = round(spec, 4)
  return patches_matriks

# %%
all_sens_spec = []

for i, (X_sub_volume, y_sub_volume) in enumerate(test_ds):
    X_sub_volume = X_sub_volume.numpy()
    y_sub_volume = y_sub_volume.numpy()

    for j in range(X_sub_volume.shape[0]):
        satu_sub_volume_image = X_sub_volume[j]
        satu_sub_volume_groundTruth = y_sub_volume[j]

        X_with_batch_dimension = np.expand_dims(satu_sub_volume_image, axis=0)
        data_sen_spe = model.predict(X_with_batch_dimension)

        threshold = 0.5
        data_sen_spe = (data_sen_spe > threshold).astype(np.float32)

        sens_spe = hitung_recall_specificity_setiap_kelas(
            data_sen_spe[0], satu_sub_volume_groundTruth
        )
        all_sens_spec.append(sens_spe)

result = pd.concat(all_sens_spec, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step

# %%
result = pd.concat(all_sens_spec, axis=1)
result_df = pd.DataFrame(result.values.T, index=result.columns, columns=result.index)

print(result_df)
# Out:
#                      Recall Specificity
# Endema               0.4853      0.4528
# Non-Enhancing Tumor  0.7078      0.6588
# Enhancing Tumor           0       0.653
# Endema               0.3768      0.4178
# Non-Enhancing Tumor  0.5954      0.6931
# ...                     ...         ...
# Non-Enhancing Tumor  0.4727       0.667
# Enhancing Tumor      0.6462         0.6
# Endema               0.5892       0.455
# Non-Enhancing Tumor  0.4342      0.6771
# Enhancing Tumor      0.7727      0.5938
#
# [345 rows x 2 columns]

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 345 entries, Endema to Enhancing Tumor
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Recall       345 non-null    object
#  1   Specificity  345 non-null    object
# dtypes: object(2)
# memory usage: 8.1+ KB

# %%
# RSU
result_df['Recall'] = result_df['Recall'].astype(float)
result_df['Specificity'] = result_df['Specificity'].astype(float)
averages = result_df.groupby(result_df.index).mean()
print(averages)
# Out:
#                        Recall  Specificity
# Endema               0.313030     0.447571
# Enhancing Tumor      0.377459     0.640803
# Non-Enhancing Tumor  0.535138     0.685857

# %%
#RSU
averages = result_df.groupby(result_df.index).mean()
recall_specificity_avg = averages.mean()
print(recall_specificity_avg)
# Out:
# Recall         0.408543
# Specificity    0.591410
# dtype: float64

# %%
# # U-Net
# result_df['Recall'] = result_df['Recall'].astype(float)
# result_df['Specificity'] = result_df['Specificity'].astype(float)
# averages = result_df.groupby(result_df.index).mean()
# print(averages)

# %%
# # U-Net
# averages = result_df.groupby(result_df.index).mean()
# recall_specificity_avg = averages.mean()
# print(recall_specificity_avg)

# %%
# result = pd.concat(all_sens_spec, axis=1)
# result.columns = ['Endema', 'Non-Enhancing Tumor', 'Enhancing Tumor'] * (len(test_generator) * X_sub_volume.shape[0])
# average_per_class = result.groupby(level=0, axis=1).mean()
# average_per_class_fix = average_per_class.reindex(columns=['Endema', 'Non-Enhancing Tumor', 'Enhancing Tumor'])
# print(average_per_class_fix)
