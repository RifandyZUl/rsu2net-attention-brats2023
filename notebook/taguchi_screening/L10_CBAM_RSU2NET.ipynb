# %% [markdown]
# ## Import Libraries

# %%
# !pip install itk --quiet
# !pip install itkwidgets --quiet
# !pip install ipywidgets --quiet

# %%
# import itk
# import itkwidgets
import cv2
import imageio
from tensorflow.keras.utils import to_categorical
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
from IPython.display import clear_output, Image
import tensorflow as tf
from tensorflow import keras
import json
import os
import pickle
import scipy.ndimage
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from IPython.display import display, HTML
from tqdm import tqdm

# %%
# !pip list > dependencies.txt

# %%
import tensorflow as tf
print(f'Versi TensorFlow: {tf.__version__}')
# Out:
# Versi TensorFlow: 2.19.0

# %% [markdown]
# ## Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BASE_DIR = '/content/drive/MyDrive/Kelly/100p_brats2023'

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# #### Data

# %%
img1_path = BASE_DIR + '/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/imagesTr/K23_1250_0002.nii.gz'
img_obj = nib.load(img1_path)
print(f'Tipe data image: {type(img_obj)}')
# Out:
# Tipe data image: <class 'nibabel.nifti1.Nifti1Image'>

# %%
img_data = img_obj.get_fdata()
type(img_data)
height, width, depth = img_data.shape
print(f'Shape gambar: height: {height}, width: {width}, depth: {depth}')
print(f'Dimensi data: {np.ndim(img_data)}')
# Out:
# Shape gambar: height: 240, width: 240, depth: 155
# Dimensi data: 3

# %% [markdown]
# #### Visualisasi Data

# %%
vol_depth = 154
i = np.random.randint(0,vol_depth)
channel = 2

print(f'Menampilkan slice gambar {i} dengan saluran: {channel}')
plt.imshow(img_data[:,:,i], cmap='gray')
# plt.axis('off')
# Out:
# Menampilkan slice gambar 98 dengan saluran: 2

# %%
BASE_CASE = '/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/imagesTr/K23_1250'

i = 80

modalities = {
    "t2f":   BASE_CASE + "_0000.nii.gz",
    "t1n":     BASE_CASE + "_0001.nii.gz",
    "t1c":   BASE_CASE + "_0002.nii.gz",
    "t2w":     BASE_CASE + "_0003.nii.gz"
}

imgs = {name: nib.load(path).get_fdata() for name, path in modalities.items()}

fig, axes = plt.subplots(1, 4, figsize=(15, 5))
for ax, (name, data) in zip(axes, imgs.items()):
    ax.imshow(data[:, :, i], cmap='gray')
    ax.set_title(name)
    ax.axis('off')

plt.suptitle(f'Slice ke-{i} dari empat modalitas', fontsize=16)
plt.show()

# %% [markdown]
# #### Interactive Visualisasi Data

# %%
BASE_CASE = '/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/imagesTr/K23_1250'
modalities = [
    ("t2f", BASE_CASE + "_0000.nii.gz"),
    ("t1n",   BASE_CASE + "_0001.nii.gz"),
    ("t1c",  BASE_CASE + "_0002.nii.gz"),
    ("t2w",   BASE_CASE + "_0003.nii.gz"),
]

vols = []
labels = []
for label, path in modalities:
    img = nib.load(path).get_fdata()
    vols.append(img)
    labels.append(label)

vol4d = np.stack(vols, axis=-1)

def img3d_explore(layer, channel=0):
    clear_output(wait=True)
    plt.figure(figsize=(6,6))
    plt.imshow(vol4d[:, :, layer, channel], cmap='gray')
    plt.title(f'Modality {channel} | Slice {layer}', fontsize=14)
    plt.axis('off')
    plt.show()
    return layer

interact(
    img3d_explore,
    layer=(0, vol4d.shape[2]-1),
    channel=(0, vol4d.shape[3]-1)
)
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), IntSlider(value=0, description='chann…
# <function __main__.img3d_explore(layer, channel=0)>

# %% [markdown]
# #### Label

# %%
label1_path = BASE_DIR + '/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/labelsTr/K23_1249.nii.gz'
label_obj = nib.load(label1_path)
type(label_obj)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
label_data = label_obj.get_fdata()
type(label_data)
height, width, depth = label_data.shape
print(f'Shape label: height: {height}, width: {width}, depth: {depth}')
# Out:
# Shape label: height: 240, width: 240, depth: 155

# %%
print(f'Nilai Unik pada label: {np.unique(label_data)}')
# Out:
# Nilai Unik pada label: [0. 1. 2. 3.]

# %%
print(np.where(label_data == 2))
# Out:
# (array([ 54,  54,  54, ..., 118, 118, 118]), array([146, 146, 147, ..., 138, 138, 138]), array([60, 61, 60, ..., 84, 85, 86]))

# %% [markdown]
# #### Visualisasi Label

# %%
layer = 80
class_dict = {
    'Necrotic Tumor Core': 1.,
    'Peritumoral Edema': 2.,
    'Enhancing Tumor': 3.
}

fig, ax = plt.subplots(nrows=1, ncols = 3, figsize=(50,10))
for i in range (3):
  img_label = list(class_dict.keys())[i]
  img = label_data[:,:,layer]
  mask = np.where(img==class_dict[img_label], 255,0)
  ax[i].imshow(mask, cmap='gray')
  ax[i].set_title(f'{img_label}', fontsize = 40)
  ax[i].axis('off')

plt.tight_layout()

# %% [markdown]
# #### Interactive Visualisasi Label

# %%
select_class = ToggleButtons(
    options=['Necrotic Tumor Core', 'Peritumoral Edema', 'Enhancing Tumor'],
    description='Pilih Class:',
    disabled=False,
    button_style='info'
)
select_layer = IntSlider(min=0, max=154, description='Pilih Layer', continuous_update=False)

def plot_image(seg_class, layer):
    clear_output(wait=True)
    print(f'Menampilkan layer {layer} | Label: {seg_class}')
    img_label = class_dict[seg_class]
    mask = np.where(label_data[:, :, layer] == img_label, 255, 0)
    plt.figure(figsize=(10,5))
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

interactive(plot_image, seg_class=select_class, layer=select_layer)
# Out:
# interactive(children=(ToggleButtons(button_style='info', description='Pilih Class:', options=('Necrotic Tumor …

# %% [markdown]
# #### Visualisasi 3D

# %%
# import numpy as np
# import nibabel as nib
# from mayavi import mlab

# # Run in pycharm
# BASE_CASE = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/imagesTr/K23_1250"
# image_flair = nib.load(BASE_CASE + "_0000.nii.gz").get_fdata()
# label = nib.load("/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/labelsTr/K23_1250.nii.gz").get_fdata()

# if image_flair.ndim == 4:
#     image_flair = image_flair[..., 0]

# mlab.figure(bgcolor=(0, 0, 0), size=(800, 600))

# src_image = mlab.pipeline.volume(
#     mlab.pipeline.scalar_field(image_flair),
#     color=(1, 1, 1)
# )

# color_map = {
#     1: (1, 0, 0),  # NCR = red
#     2: (0, 1, 0),  # ED = green
#     3: (0, 0, 1)   # ET = blue
# }

# for label_class, color in color_map.items():
#     labeled_volume = np.where(label == label_class, 1, 0)
#     src = mlab.pipeline.volume(
#         mlab.pipeline.scalar_field(labeled_volume),
#         color=color
#     )

# mlab.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ##### Voxel dan Standarisasi

# %%
import glob
import os

BASE_PATH = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023"
label_files = sorted(glob.glob(os.path.join(BASE_DIR, "labelsTr", "*.nii.gz")))


label_files = sorted(
    glob.glob(os.path.join(BASE_PATH, "labelsTr", "*.nii.gz"))
)
print("Found label files:", len(label_files))

if label_files:
    lbl_file = label_files[0]
    print("Example label file:", lbl_file)

    label = nib.load(lbl_file).get_fdata()
    print("Shape:", label.shape)

total_voxels = np.prod(label.shape)
tumor_voxels = np.sum(label > 0)
print("Tumor ratio:", tumor_voxels / total_voxels)
# Out:
# Found label files: 1251
# Example label file: /content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023/labelsTr/K23_0000.nii.gz
# Shape: (240, 240, 155)
# Tumor ratio: 0.006418570788530466

# %%
def standarisasi(image):
  standarisasi_image = np.zeros(image.shape)
  for c in range(image.shape[0]):
    for z in range(image.shape[3]):
      image_slice = image[c,:,:,z]
      centered = image_slice - np.mean(image_slice)
      centered_scaled = centered / np.std(centered)
      standarisasi_image[c,:,:,z] = centered_scaled
  return standarisasi_image

def get_sub_volume(image, label,
                   orig_x = 240, orig_y = 240, orig_z = 155,
                   output_x = 160, output_y = 160, output_z = 16,
                   num_classes = 4, max_tries = 100,
                   background_threshold=0.995):
  X = None
  y = None
  start_x = None
  start_y = None
  start_z = None

  tries = 0
  while tries < max_tries:
    start_x = np.random.randint(0 , orig_x - output_x + 1)
    start_y = np.random.randint(0 , orig_y - output_y + 1)
    start_z = np.random.randint(0 , orig_z - output_z + 1)

    y = label[start_x: start_x + output_x,
              start_y: start_y + output_y,
              start_z: start_z + output_z]

    y = to_categorical(y, num_classes = num_classes)

    bgrd_ratio = np.sum(y[:,:,:,0]) / (output_x * output_y * output_z)

    tries += 1

    if bgrd_ratio < background_threshold:

        X = np.copy(image[start_x: start_x + output_x,
                          start_y: start_y + output_y,
                          start_z: start_z + output_z, :])

        X = np.moveaxis(X,3,0)
        X = standarisasi(X)
        y = np.moveaxis(y,3,0)
        y = y[1:, :, :, :]

        return X, y, start_x, start_y, start_z

    print(f"Percobaan ke-{tries} untuk menemukan sub-volume")

# %% [markdown]
# Crop preprocessed segmentation

# %%
# from tqdm import tqdm
# import os, pickle, numpy as np, nibabel as nib, scipy.ndimage

# PP_stage = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_preprocessed/Task001_BraTS2023/nnUNetData_plans_v2.1_trgSp_1x1x1_stage0"
# PP_gt    = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_preprocessed/Task001_BraTS2023/gt_segmentations"
# OUT_DIR  = "/content/drive/MyDrive/Kelly/RSUU2Net/sub_volumes"
# os.makedirs(OUT_DIR, exist_ok=True)

# pkl_files = sorted([f for f in os.listdir(PP_stage) if f.endswith(".pkl")])

# for pkl_file in tqdm(pkl_files, desc="Rebuilding seg masks (canonical → crop → resample)"):
#     case_id  = pkl_file[:-4]
#     pkl_path = os.path.join(PP_stage, pkl_file)
#     seg_path = os.path.join(PP_gt, f"{case_id}.nii.gz")

#     with open(pkl_path, "rb") as f:
#         meta = pickle.load(f)
#     (x1,x2), (y1,y2), (z1,z2) = meta["crop_bbox"]
#     target_shape = tuple(meta["size_after_resampling"])

#     seg_ras = nib.as_closest_canonical(nib.load(seg_path)).get_fdata().astype(np.uint8)

#     seg_crop = seg_ras[x1:x2, y1:y2, z1:z2]

#     zoom = np.array(target_shape) / np.array(seg_crop.shape)
#     seg_resampled = scipy.ndimage.zoom(seg_crop, zoom=zoom, order=0)

#     np.save(os.path.join(OUT_DIR, f"{case_id}_seg.npy"), seg_resampled)

# print(f"Done. Saved to {OUT_DIR}")

# %%
# import numpy as np, matplotlib.pyplot as plt

# case_id   = "K23_1239"
# stage_dir = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_preprocessed/Task001_BraTS2023/nnUNetData_plans_v2.1_trgSp_1x1x1_stage0"
# seg_dir   = "/content/drive/MyDrive/Kelly/RSUU2Net/sub_volumes"

# image = np.load(f"{stage_dir}/{case_id}.npz")["data"]         # (C, X, Y, Z)
# seg   = np.load(f"{seg_dir}/{case_id}_seg.npy")               # (X, Y, Z)

# print("Image shape:", image.shape)
# print("Seg shape:",   seg.shape)

# modality = 0                       # pick the channel you want to view
# z = seg.shape[-1] // 2             # middle slice
# mri = image[modality, :, :, z]
# mask = seg[:, :, z]

# plt.figure(figsize=(6,6))
# plt.imshow(mri, cmap="gray")
# plt.imshow(np.ma.masked_where(mask == 0, mask), cmap="jet", alpha=0.5)
# plt.title(f"Case {case_id} | Modality {modality} | Slice {z}")
# plt.axis("off")
# plt.show()

# %% [markdown]
# ##### Menyimpan Voxel

# %%
# import os
# import glob
# import nibabel as nib
# import numpy as np
# import h5py
# import json


# def stack_modalities(case_id, base_dir):
#     """Stack 4 modality files (0000–0003) into one 4D array (H,W,D,4)."""
#     files = [
#         f"{base_dir}/imagesTr/{case_id}_0000.nii.gz",
#         f"{base_dir}/imagesTr/{case_id}_0001.nii.gz",
#         f"{base_dir}/imagesTr/{case_id}_0002.nii.gz",
#         f"{base_dir}/imagesTr/{case_id}_0003.nii.gz"
#     ]
#     vols = [nib.load(f).get_fdata() for f in files]
#     return np.stack(vols, axis=-1)


# def load_data(img_file, lbl_file):
#     if isinstance(img_file, str):
#         image = np.array(nib.load(img_file).get_fdata())
#     else:
#         image = img_file
#     label = np.array(nib.load(lbl_file).get_fdata())
#     return image, label


# def save_sub_volumes_all_images(num_sub_volumes, output_dir, case_id, base_dir, lbl_file, max_attempts=50):
#     if not os.path.exists(output_dir):
#         os.makedirs(output_dir)

#     image = stack_modalities(case_id, base_dir)
#     label = np.array(nib.load(lbl_file).get_fdata())

#     sub_volume_generated = False
#     attempts = 0

#     for i in range(1, num_sub_volumes+1):
#         sub_vol = get_sub_volume(image, label)

#         while (sub_vol is not None and np.isnan(sub_vol[0]).any()) and attempts < max_attempts:
#             print(f"Sub-volume {i} for {case_id} Terdapat nan value. Generate yang baru.")
#             sub_vol = get_sub_volume(image, label)
#             attempts += 1

#         if attempts == max_attempts or sub_vol is None:
#             print(f"Gagal mendapatkan sub-volume tanpa NaN setelah {max_attempts} atau sub volume adalah None. Melanjutkan ke gambar berikutnya.")
#             break

#         X, y, start_x, start_y, start_z = sub_vol
#         h5_file = os.path.join(
#             output_dir,
#             f"{case_id}_{i}_x{start_x}_y{start_y}_z{start_z}.h5"
#         )
#         with h5py.File(h5_file, 'w') as hf:
#             hf.create_dataset('x', data=X, compression='gzip', compression_opts=9)
#             hf.create_dataset('y', data=y, compression='gzip', compression_opts=9)

#         sub_volume_generated = True

#     if not sub_volume_generated:
#         print(f"Tidak ada sub-volume yang memenuhi kriteria untuk {case_id}")


# BASE_DIR = "/content/drive/MyDrive/Kelly/100p_brats2023/nnUNet_raw/nnUNet_raw_data/Task001_BraTS2023"
# OUTPUT_DIR = "/content/drive/MyDrive/Kelly/RSUU2Net/sub_volume"

# label_files = sorted(glob.glob(os.path.join(BASE_DIR, "labelsTr", "*.nii.gz")))
# cases = [os.path.basename(f).replace(".nii.gz", "") for f in label_files]

# for case_id, lbl_file in zip(cases, label_files):
#     print(f"Processing {case_id} ...")
#     save_sub_volumes_all_images(5, OUTPUT_DIR, case_id, BASE_DIR, lbl_file)
# Out:
# Processing K23_0000 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0001 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0002 ...
# /tmp/ipython-input-3184774874.py:7: RuntimeWarning: invalid value encountered in divide
#   centered_scaled = centered / np.std(centered)
# Sub-volume 1 for K23_0002 Terdapat nan value. Generate yang baru.
# Percobaan ke-1 untuk menemukan sub-volume
# Sub-volume 5 for K23_0002 Terdapat nan value. Generate yang baru.
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0003 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0004 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Processing K23_0005 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Processing K23_0006 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0007 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0008 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0009 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0010 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0011 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0012 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0013 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0014 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0015 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0016 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0017 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0018 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0019 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0020 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Processing K23_0021 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Processing K23_0022 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0023 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0024 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0025 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0026 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Processing K23_0027 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0028 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0029 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0030 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0031 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0032 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0033 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0034 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0035 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0036 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0037 ...
# Processing K23_0038 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0039 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0040 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0041 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0042 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Percobaan ke-12 untuk menemukan sub-volume
# Percobaan ke-13 untuk menemukan sub-volume
# Percobaan ke-14 untuk menemukan sub-volume
# Percobaan ke-15 untuk menemukan sub-volume
# Percobaan ke-16 untuk menemukan sub-volume
# Percobaan ke-17 untuk menemukan sub-volume
# Processing K23_0043 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0044 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0045 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Processing K23_0046 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0047 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0048 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0049 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0050 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0051 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0052 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0053 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0054 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Processing K23_0055 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0056 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0057 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0058 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0059 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Percobaan ke-12 untuk menemukan sub-volume
# Percobaan ke-13 untuk menemukan sub-volume
# Percobaan ke-14 untuk menemukan sub-volume
# Percobaan ke-15 untuk menemukan sub-volume
# Percobaan ke-16 untuk menemukan sub-volume
# Percobaan ke-17 untuk menemukan sub-volume
# Percobaan ke-18 untuk menemukan sub-volume
# Percobaan ke-19 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Processing K23_0060 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0061 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0062 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Percobaan ke-12 untuk menemukan sub-volume
# Percobaan ke-13 untuk menemukan sub-volume
# Processing K23_0063 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0064 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0065 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0066 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0067 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0068 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0069 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Percobaan ke-12 untuk menemukan sub-volume
# Processing K23_0070 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Processing K23_0071 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0072 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0073 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0074 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0075 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Percobaan ke-12 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0076 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Processing K23_0077 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0078 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0079 ...
# Processing K23_0080 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0081 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0082 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0083 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0084 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0085 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0086 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0087 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0088 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0089 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Processing K23_0090 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0091 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0092 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0093 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0094 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0095 ...
# Sub-volume 1 for K23_0095 Terdapat nan value. Generate yang baru.
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0096 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0097 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0098 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0099 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Sub-volume 5 for K23_0099 Terdapat nan value. Generate yang baru.
# Processing K23_0100 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0101 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0102 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Processing K23_0103 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0104 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0105 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0106 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0107 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0108 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0109 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0110 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0111 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0112 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0113 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0114 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0115 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0116 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Processing K23_0117 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0118 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0119 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0120 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0121 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0122 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0123 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0124 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0125 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Processing K23_0126 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0127 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0128 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0129 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0130 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0131 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0132 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0133 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0134 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0135 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0136 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0137 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Percobaan ke-12 untuk menemukan sub-volume
# Percobaan ke-13 untuk menemukan sub-volume
# Percobaan ke-14 untuk menemukan sub-volume
# Percobaan ke-15 untuk menemukan sub-volume
# Percobaan ke-16 untuk menemukan sub-volume
# Processing K23_0138 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0139 ...
# Processing K23_0140 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0141 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0142 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0143 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0144 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Processing K23_0145 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0146 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0147 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0148 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# ...
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0400 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0401 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0402 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0403 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0404 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0405 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0406 ...
# Processing K23_0407 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0408 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0409 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0410 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0411 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0412 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0413 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0414 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0415 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0416 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0417 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0418 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0419 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0420 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0421 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0422 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0423 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0424 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0425 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0426 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0427 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0428 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Percobaan ke-12 untuk menemukan sub-volume
# Percobaan ke-13 untuk menemukan sub-volume
# Processing K23_0429 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Percobaan ke-11 untuk menemukan sub-volume
# Processing K23_0430 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0431 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0432 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Percobaan ke-9 untuk menemukan sub-volume
# Percobaan ke-10 untuk menemukan sub-volume
# Processing K23_0433 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0434 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0435 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0436 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0437 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Processing K23_0438 ...
# Processing K23_0439 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Percobaan ke-6 untuk menemukan sub-volume
# Percobaan ke-7 untuk menemukan sub-volume
# Percobaan ke-8 untuk menemukan sub-volume
# Processing K23_0440 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0441 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Sub-volume 2 for K23_0441 Terdapat nan value. Generate yang baru.
# Sub-volume 3 for K23_0441 Terdapat nan value. Generate yang baru.
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0442 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Processing K23_0443 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Percobaan ke-3 untuk menemukan sub-volume
# Percobaan ke-4 untuk menemukan sub-volume
# Percobaan ke-5 untuk menemukan sub-volume
# Processing K23_0444 ...
# Processing K23_0445 ...
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-1 untuk menemukan sub-volume
# Percobaan ke-2 untuk menemukan sub-volume
# Processing K23_0446 ...

# %%
import h5py
def visualize_patch(X, y):
    fig, ax = plt.subplots(1, 2, figsize=[10, 5], squeeze=False)

    ax[0][0].imshow(X[:, :, 0], cmap='gray')
    ax[0][0].set_yticks([])
    ax[0][0].set_xticks([])
    ax[0][1].imshow(y[:, :, 0], cmap='viridis')
    ax[0][1].set_xticks([])
    ax[0][1].set_yticks([])

    fig.subplots_adjust(wspace=0, hspace=0)

file_name = '/content/drive/MyDrive/Kelly/RSUU2Net/sub_volume/K23_1250_5_x50_y68_z84.h5'

with h5py.File(file_name, 'r') as hf:
    image_data = hf['x'][:]
    label_data = hf['y'][:]
print(image_data.shape)
print(label_data.shape)
visualize_patch(image_data[2], label_data[0])

plt.show()
# Out:
# (4, 160, 160, 16)
# (3, 160, 160, 16)

# %%
# import os
# import shutil
# import random
# import json

# all_dir = '/content/drive/MyDrive/Kelly/RSUU2Net/sub_volume'
# temp_dir = '/content/RSUU2Net_splits'
# train_dir = os.path.join(temp_dir, 'training')
# val_dir   = os.path.join(temp_dir, 'validation')
# test_dir  = os.path.join(temp_dir, 'testing')

# for d in [train_dir, val_dir, test_dir]:
#     os.makedirs(d, exist_ok=True)

# all_h5_files = [f for f in os.listdir(all_dir) if f.endswith('.h5')]

# def get_case_id(filename):
#     return "_".join(filename.split("_")[:2])

# case_ids = sorted(set(get_case_id(f) for f in all_h5_files))

# random.seed(42)
# random.shuffle(case_ids)

# n_total = len(case_ids)
# n_train = int(0.7 * n_total)
# n_val   = int(0.15 * n_total)
# n_test  = n_total - n_train - n_val

# train_cases = case_ids[:n_train]
# val_cases   = case_ids[n_train:n_train+n_val]
# test_cases  = case_ids[n_train+n_val:]

# train_files, val_files, test_files = [], [], []

# for f in all_h5_files:
#     case_id = get_case_id(f)
#     src = os.path.join(all_dir, f)
#     if case_id in train_cases:
#         shutil.copy(src, os.path.join(train_dir, f))
#         train_files.append(f)
#     elif case_id in val_cases:
#         shutil.copy(src, os.path.join(val_dir, f))
#         val_files.append(f)
#     else:
#         shutil.copy(src, os.path.join(test_dir, f))
#         test_files.append(f)

# final_data = {
#     "training": sorted(train_files),
#     "validation": sorted(val_files),
#     "testing": sorted(test_files)
# }

# config_path = os.path.join(temp_dir, "configurasi.json")
# with open(config_path, 'w') as json_file:
#     json.dump(final_data, json_file, indent=4)

# print(f"Split {n_total} cases into {n_train} train, {n_val} val, {n_test} test.")
# print("Saved locally at:", temp_dir)

# drive_target = "/content/drive/MyDrive/Kelly/RSUU2Net"
# shutil.copytree(temp_dir, drive_target, dirs_exist_ok=True)
# print(f"Copied results back to Drive: {drive_target}")
# Out:
# Split 1251 cases into 875 train, 187 val, 189 test.
# Saved locally at: /content/RSUU2Net_splits
# Copied results back to Drive: /content/drive/MyDrive/Kelly/RSUU2Net

# %%
import os
import json

direktori_train = '/content/drive/MyDrive/Kelly/RSUU2Net/training'
direktori_val = '/content/drive/MyDrive/Kelly/RSUU2Net/validation'
direktori_test = '/content/drive/MyDrive/Kelly/RSUU2Net/testing'

def collect_h5_files(directory):
    h5_files = [file for file in os.listdir(directory) if file.endswith(".h5")]
    return sorted(h5_files)

train_h5_files = collect_h5_files(direktori_train)
val_h5_files = collect_h5_files(direktori_val)
test_h5_files = collect_h5_files(direktori_test)

final_data = {"training": train_h5_files, "validation": val_h5_files, "testing": test_h5_files}

with open('configurasi.json', 'w') as json_file:
    json.dump(final_data, json_file, indent=4)

# %%
import os
import matplotlib.pyplot as plt
import random

def get_case_id(filename):
    return "_".join(filename.split("_")[:2])

def get_unique_cases(directory):
    files = [f for f in os.listdir(directory) if f.endswith(".h5")]
    case_ids = list(set(get_case_id(f) for f in files))
    return case_ids

def sample_cases(case_ids, percentage=0.1):
    random.shuffle(case_ids)
    sample_size = int(len(case_ids) * percentage)
    return case_ids[:sample_size]

train_dir = '/content/drive/MyDrive/Kelly/RSUU2Net/training'
val_dir   = '/content/drive/MyDrive/Kelly/RSUU2Net/validation'
test_dir  = '/content/drive/MyDrive/Kelly/RSUU2Net/testing'

train_ids = get_unique_cases(train_dir)
val_ids   = get_unique_cases(val_dir)
test_ids  = get_unique_cases(test_dir)

# jumlah_data = [len(train_sample), len(val_sample), len(test_sample)]

# num_cases_train, train_ids = count_unique_cases(train_dir)
# num_cases_val, val_ids     = count_unique_cases(val_dir)
# num_cases_test, test_ids   = count_unique_cases(test_dir)

train_sample = sample_cases(train_ids, 0.1)
val_sample   = sample_cases(val_ids, 0.1)
test_sample  = sample_cases(test_ids, 0.1)
jumlah_data = [len(train_sample), len(val_sample), len(test_sample)]

print("Training cases\t\t:", len(train_sample))
print("Validation cases\t:", len(val_sample))
print("Testing cases\t\t:", len(test_sample))
print("==========================")
print("Total cases\t\t\t:", sum(jumlah_data), "\n")

labels = ['Training', 'Validation', 'Testing']

plt.figure(figsize=(8,6))
plt.bar(labels, jumlah_data)
plt.xlabel('Subset Data')
plt.ylabel('Jumlah Kasus')
plt.title('Jumlah Kasus')
plt.show()
# Out:
# Training cases		: 87
# Validation cases	: 18
# Testing cases		: 18
# ==========================
# Total cases			: 123

# %%
print(f'Data training\t\t: {len(train_sample)}')
print(f'Data validation\t\t: {len(val_sample)}')
print(f'Data testing\t\t: {len(test_sample)} \n')

jumlah_data = [len(train_sample), len(val_sample), len(test_sample)]
# jumlah_data = [num_cases_train, num_cases_val, num_cases_test]
labels = ['Training', 'Validation', 'Testing']

# persentase_data = [num / sub_volume * 100 for num in jumlah_data]
total = sum(jumlah_data)
persentase_data = [(num / total) * 100 for num in jumlah_data]
# persentase_data = [num / sub_volume * 100 for num in jumlah_data]

plt.figure(figsize=(8, 6))
colors = ['gold', 'lightblue', 'lightgreen']
plt.pie(persentase_data, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Sebaran Pembagian Data', pad=30)
plt.axis('equal')
plt.show()
# Out:
# Data training		: 87
# Data validation		: 18
# Data testing		: 18

# %% [markdown]
# ##### Generator

# %%
# import h5py
# import numpy as np
# class VolumeDataGenerator(tf.keras.utils.Sequence):
#     def __init__(self,
#                  sample_list,
#                  base_dir,
#                  batch_size=1,
#                  shuffle=True,
#                  dim=(160, 160, 16),
#                  num_channels=4,
#                  num_classes=3,
#                  verbose=1,
#                  seed=42, **kwargs):
#         super().__init__(**kwargs)

#         self.batch_size = batch_size
#         self.shuffle = shuffle
#         self.base_dir = base_dir
#         self.dim = dim
#         self.num_channels = num_channels
#         self.num_classes = num_classes
#         self.verbose = verbose
#         self.seed = seed
#         self.sample_list = sample_list
#         self.on_epoch_end()

#     def on_epoch_end(self):
#         self.indexes = np.arange(len(self.sample_list))
#         if self.shuffle == True:
#             np.random.seed(self.seed)
#             np.random.shuffle(self.indexes)

#     def __len__(self):
#         return int(np.floor(len(self.sample_list) / self.batch_size))

#     def __data_generation(self, list_IDs_temp):
#         X = np.zeros((self.batch_size, self.num_channels, *self.dim),
#                      dtype=np.float32)
#         y = np.zeros((self.batch_size, self.num_classes, *self.dim),
#                      dtype=np.float32)

#         for i, ID in enumerate(list_IDs_temp):
#             if self.verbose == 1:
#                 print("Training on: %s" % self.base_dir + ID)
#             with h5py.File(self.base_dir + ID, 'r') as f:
#                 X[i] = np.array(f.get("x"))
#                 y[i] = np.array(f.get("y"))
#         return X, y

#     def __getitem__(self, index):
#         indexes = self.indexes[
#                   index * self.batch_size: (index + 1) * self.batch_size]
#         sample_list_temp = [self.sample_list[k] for k in indexes]
#         X, y = self.__data_generation(sample_list_temp)

#         return X, y

# %%
def load_h5_file(path, num_channels=4, num_classes=3, dim=(160,160,16)):
    def _py_load(path_bytes):
        # Ensure we get a proper string path
        if isinstance(path_bytes, (np.ndarray, np.generic)):
            path_str = path_bytes.item().decode("utf-8") if isinstance(path_bytes.item(), (bytes, bytearray)) else str(path_bytes.item())
        elif isinstance(path_bytes, (bytes, bytearray)):
            path_str = path_bytes.decode("utf-8")
        else:
            path_str = str(path_bytes)

        with h5py.File(path_str, "r") as f:
            x = np.array(f["x"], dtype=np.float32)
            y = np.array(f["y"], dtype=np.float32)
        return x, y

    x, y = tf.numpy_function(
        _py_load, [path], [tf.float32, tf.float32]
    )
    x.set_shape((num_channels, *dim))
    y.set_shape((num_classes, *dim))
    return x, y

# %%
# def build_dataset(file_list, base_dir, batch_size=2, shuffle=True):
#     paths = [os.path.join(base_dir, f) for f in file_list]
#     ds = tf.data.Dataset.from_tensor_slices(paths)

#     if shuffle:
#         ds = ds.shuffle(buffer_size=len(paths), reshuffle_each_iteration=True)

#     ds = ds.map(
#         lambda path: load_h5_file(path),
#         num_parallel_calls=tf.data.AUTOTUNE
#     )

#     ds = ds.batch(batch_size)
#     ds = ds.prefetch(tf.data.AUTOTUNE)
#     return ds

# %%
# tes_dir = "/content/drive/MyDrive/Kelly/RSUU2Net"
# with open(tes_dir + "/configurasi.json") as json_file:
#     config = json.load(json_file)

# train_ds = build_dataset(config["training"], os.path.join(tes_dir, "training"), batch_size=2)
# val_ds   = build_dataset(config["validation"], os.path.join(tes_dir, "validation"), batch_size=2, shuffle=False)
# test_ds  = build_dataset(config["testing"], os.path.join(tes_dir, "testing"), batch_size=2, shuffle=False)

# %%
# tes_dir = "/content/drive/MyDrive/Kelly/RSUU2Net"
# with open(tes_dir + "/configurasi.json") as json_file:
#   config = json.load(json_file)

# %%
# train_generator = VolumeDataGenerator(config["training"], "/content/drive/MyDrive/Kelly/RSUU2Net/training/", batch_size=2, dim = (160,160,16), verbose=2)
# valid_generator = VolumeDataGenerator(config["validation"], "/content/drive/MyDrive/Kelly/RSUU2Net/validation/", batch_size=2, dim = (160,160,16), verbose=2)
# test_generator = VolumeDataGenerator(config["testing"], "/content/drive/MyDrive/Kelly/RSUU2Net/testing/", batch_size=2, dim = (160,160,16), verbose=2)

# %%
def build_dataset(file_list, batch_size=2, shuffle=True):
    ds = tf.data.Dataset.from_tensor_slices(file_list)

    if shuffle:
        ds = ds.shuffle(buffer_size=len(file_list))

    ds = ds.map(
        lambda path: load_h5_file(path),
        num_parallel_calls=tf.data.AUTOTUNE
    )

    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# %%
def filter_files_by_case(directory, selected_cases):
    files = os.listdir(directory)
    filtered = [
        os.path.join(directory, f)
        for f in files
        if f.endswith(".h5") and get_case_id(f) in selected_cases
    ]
    return filtered

# %%
train_files = filter_files_by_case(train_dir, train_sample)
val_files   = filter_files_by_case(val_dir, val_sample)
test_files  = filter_files_by_case(test_dir, test_sample)

# %%
tes_dir = "/content/drive/MyDrive/Kelly/RSUU2Net"
with open(tes_dir + "/configurasi.json") as json_file:
    config = json.load(json_file)

# %%
train_ds = build_dataset(train_files, batch_size=2, shuffle=True)
val_ds   = build_dataset(val_files, batch_size=2, shuffle=False)
test_ds  = build_dataset(test_files, batch_size=2, shuffle=False)

# %%
print("Train files:", len(train_files))
print("Val files:", len(val_files))
# Out:
# Train files: 624
# Val files: 125

# %% [markdown]
# ### Eksplorasi Preprocessed Data

# %% [markdown]
# ## Desain Arsitektur dan Training Model

# %% [markdown]
# ### Loss Function and Metrics

# %%
# from tensorflow.keras import backend as K
# import numpy as np

# def soft_dice_loss(y_true, y_pred, axis=(1, 2, 3),
#                    epsilon=0.00001):
#     dice_numerator = 2 * K.sum(y_true * y_pred , axis= axis) + epsilon
#     dice_denominator = K.sum(y_true ** 2, axis= axis) + K.sum(y_pred ** 2 , axis = axis) + epsilon
#     dice_loss = 1 - K.mean(dice_numerator / dice_denominator)
#     return dice_loss

# # def focal_dice_loss(y_true, y_pred, gamma=2, alpha=0.5, axis=(1, 2, 3), epsilon=1e-5):
# #     dice_numerator = 2 * K.sum(y_true * y_pred, axis=axis) + epsilon
# #     dice_denominator = K.sum(y_true ** 2, axis=axis) + K.sum(y_pred ** 2, axis=axis) + epsilon
# #     dice_coefficient = dice_numerator / dice_denominator
# #     pt = (dice_numerator + epsilon) / (dice_denominator + epsilon)
# #     focal_loss = -alpha * (1 - pt)**gamma * K.log(pt)
# #     return K.mean(focal_loss + (1 - dice_coefficient))

# def dice_coefficient(y_true, y_pred, axis=(1, 2, 3), epsilon=0.00001):
#     dice_numerator = 2 * K.sum(y_true * y_pred , axis = axis) + epsilon
#     dice_denominator = K.sum(y_true, axis = axis ) + K.sum(y_pred, axis = axis) + epsilon
#     dice_coefficient = K.mean(dice_numerator/dice_denominator)
#     return dice_coefficient

# def mean_iou(y_true, y_pred, axis=(1, 2, 3), epsilon=0.00001):
#     intersection = K.sum(y_true * y_pred, axis=axis)
#     union = K.sum(y_true, axis=axis) + K.sum(y_pred, axis=axis) - intersection + epsilon
#     iou = (intersection + epsilon) / (union + epsilon)
#     iou_mean = K.mean(iou)
#     return iou_mean
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5144/3653142032.py in <cell line: 0>()
# ----> 1 from tensorflow.keras import backend as K
#       2 import numpy as np
#       3
#       4 def soft_dice_loss(y_true, y_pred, axis=(1, 2, 3),
#       5                    epsilon=0.00001):
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/__init__.py in <module>
#      47 _tf2.enable()
#      48
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/__init__.py in <module>
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#      13 from tensorflow._api.v2.__internal__ import feature_column
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/distribute/__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#      10 from tensorflow._api.v2.__internal__.distribute import multi_process_runner
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/distribute/combinations/__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#      10 from tensorflow.python.distribute.combinations import in_main_process # line: 418
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/combinations.py in <module>
#      31
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_process_runner
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/collective_all_reduce_strategy.py in <module>
#      31 from tensorflow.python.distribute import input_lib
#      32 from tensorflow.python.distribute import input_util
# ---> 33 from tensorflow.python.distribute import mirrored_strategy
#      34 from tensorflow.python.distribute import multi_worker_util
#      35 from tensorflow.python.distribute import numpy_dataset
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/mirrored_strategy.py in <module>
#      32 from tensorflow.python.distribute import values
#      33 from tensorflow.python.distribute import values_util
# ---> 34 from tensorflow.python.distribute.cluster_resolver import tfconfig_cluster_resolver
#      35 from tensorflow.python.distribute.v1 import input_lib as input_lib_v1
#      36 from tensorflow.python.eager import context
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/cluster_resolver/__init__.py in <module>
#      25 from tensorflow.python.distribute.cluster_resolver.cluster_resolver import SimpleClusterResolver
#      26 from tensorflow.python.distribute.cluster_resolver.cluster_resolver import UnionClusterResolver
# ---> 27 from tensorflow.python.distribute.cluster_resolver.gce_cluster_resolver import GCEClusterResolver
#      28 from tensorflow.python.distribute.cluster_resolver.kubernetes_cluster_resolver import KubernetesClusterResolver
#      29 from tensorflow.python.distribute.cluster_resolver.slurm_cluster_resolver import SlurmClusterResolver
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/cluster_resolver/gce_cluster_resolver.py in <module>
#      22 _GOOGLE_API_CLIENT_INSTALLED = True
#      23 try:
# ---> 24   from googleapiclient import discovery  # pylint: disable=g-import-not-at-top
#      25   from oauth2client.client import GoogleCredentials  # pylint: disable=g-import-not-at-top
#      26 except ImportError:
#
# /usr/local/lib/python3.12/dist-packages/googleapiclient/discovery.py in <module>
#      40 import urllib
#      41
# ---> 42 import google.api_core.client_options
#      43 from google.auth.exceptions import MutualTLSChannelError
#      44 from google.auth.transport import mtls
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/__init__.py in <module>
#      38
#      39 # perform version checks against api_core, and emit warnings if needed
# ---> 40 check_python_version(package="google.api_core")
#      41 check_dependency_versions("google.api_core")
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/_python_version_support.py in check_python_version(package, today)
#     208     """
#     209     today = today or datetime.date.today()
# --> 210     package_label, _ = _get_distribution_and_import_packages(package)
#     211
#     212     python_version = sys.version_info
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/_python_version_support.py in _get_distribution_and_import_packages(import_package)
#     187 def _get_distribution_and_import_packages(import_package: str) -> Tuple[str, Any]:
#     188     """Return a pretty string with distribution & import package names."""
# --> 189     distribution_package = _get_pypi_package_name(import_package)
#     190     dependency_distribution_and_import_packages = (
#     191         f"package {distribution_package} ({import_package})"
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/_python_version_support.py in _get_pypi_package_name(module_name)
#     169         try:
#     170             # Get the mapping of modules to distributions
# --> 171             module_to_distributions = metadata.packages_distributions()
#     172
#     173             # Check if the module is found in the mapping
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in packages_distributions()
#     945     pkg_to_dist = collections.defaultdict(list)
#     946     for dist in distributions():
# --> 947         for pkg in _top_level_declared(dist) or _top_level_inferred(dist):
#     948             pkg_to_dist[pkg].append(dist.metadata['Name'])
#     949     return dict(pkg_to_dist)
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in _top_level_inferred(dist)
#     957     opt_names = {
#     958         f.parts[0] if len(f.parts) > 1 else inspect.getmodulename(f)
# --> 959         for f in always_iterable(dist.files)
#     960     }
#     961
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in files(self)
#     498             return list(filter(lambda path: path.locate().exists(), package_paths))
#     499
# --> 500         return skip_missing_files(
#     501             make_files(
#     502                 self._read_files_distinfo()
#
# /usr/lib/python3.12/importlib/metadata/_functools.py in wrapper(param, *args, **kwargs)
#     100     def wrapper(param, *args, **kwargs):
#     101         if param is not None:
# --> 102             return func(param, *args, **kwargs)
#     103
#     104     return wrapper
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in skip_missing_files(package_paths)
#     496         @pass_none
#     497         def skip_missing_files(package_paths):
# --> 498             return list(filter(lambda path: path.locate().exists(), package_paths))
#     499
#     500         return skip_missing_files(
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in <lambda>(path)
#     496         @pass_none
#     497         def skip_missing_files(package_paths):
# --> 498             return list(filter(lambda path: path.locate().exists(), package_paths))
#     499
#     500         return skip_missing_files(
#
# /usr/lib/python3.12/pathlib.py in exists(self, follow_symlinks)
#     858         """
#     859         try:
# --> 860             self.stat(follow_symlinks=follow_symlinks)
#     861         except OSError as e:
#     862             if not _ignore_error(e):
#
# /usr/lib/python3.12/pathlib.py in stat(self, follow_symlinks)
#     838         os.stat() does.
#     839         """
# --> 840         return os.stat(self, follow_symlinks=follow_symlinks)
#     841
#     842     def lstat(self):
#
# KeyboardInterrupt:

# %%
from tensorflow.keras import backend as K

def soft_dice_loss(y_true, y_pred, epsilon=1e-5):
    # sum over spatial dims only
    axis = (2, 3, 4)

    numerator = 2.0 * K.sum(y_true * y_pred, axis=axis) + epsilon
    denominator = K.sum(y_true, axis=axis) + K.sum(y_pred, axis=axis) + epsilon

    dice_per_class = numerator / denominator
    return 1.0 - K.mean(dice_per_class)


def dice_coefficient(y_true, y_pred, epsilon=1e-5):
    axis = (2, 3, 4)

    numerator = 2.0 * K.sum(y_true * y_pred, axis=axis) + epsilon
    denominator = K.sum(y_true, axis=axis) + K.sum(y_pred, axis=axis) + epsilon

    dice_per_class = numerator / denominator
    return K.mean(dice_per_class)


def mean_iou(y_true, y_pred, epsilon=1e-5):
    axis = (2, 3, 4)

    intersection = K.sum(y_true * y_pred, axis=axis)
    union = K.sum(y_true + y_pred, axis=axis) - intersection + epsilon

    iou_per_class = (intersection + epsilon) / union
    return K.mean(iou_per_class)

# %% [markdown]
# ### UNet Architecture

# %%
from tensorflow.keras.layers import Input, Activation, Conv3D, Conv3DTranspose, MaxPooling3D, UpSampling3D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
tf.keras.backend.set_image_data_format('channels_first')

def create_convolution_block(input_layer, n_filters, batch_normalization=False,
                             kernel=(3, 3, 3), activation=None,
                             padding='same', strides=(1, 1, 1),
                             instance_normalization=False):

    layer = Conv3D(n_filters, kernel, padding=padding, strides=strides)(input_layer)
    if activation is None:
        return Activation('relu')(layer)
    else:
        return activation()(layer)

def get_up_convolution(n_filters, pool_size, kernel_size=(2, 2, 2),
                       strides=(2, 2, 2),
                       deconvolution=False):
    if deconvolution:
        return Conv3DTranspose(filters=n_filters, kernel_size=kernel_size, strides=strides)
    else:
        return UpSampling3D(size=pool_size)

def unet_model_3d(loss_function, input_shape=(4, 160, 160, 16),
                  pool_size=(2, 2, 2), n_labels=3,
                  initial_learning_rate=0.00001,
                  deconvolution=False, depth=4, n_base_filters=32,
                  include_label_wise_dice_coefficients=False, metrics=[],
                  batch_normalization=False, activation_name="sigmoid"):

    inputs = Input(input_shape)
    current_layer = inputs
    levels = list()

    for layer_depth in range(depth):
        layer1 = create_convolution_block(input_layer=current_layer,
                                          n_filters=n_base_filters * (2 ** layer_depth),
                                          batch_normalization=batch_normalization)
        layer2 = create_convolution_block(input_layer=layer1,
                                          n_filters=n_base_filters * (2 ** layer_depth) * 2,
                                          batch_normalization=batch_normalization)
        if layer_depth < depth - 1:
            current_layer = MaxPooling3D(pool_size=pool_size)(layer2)
            levels.append([layer1, layer2, current_layer])
        else:
            current_layer = layer2
            levels.append([layer1, layer2])

    for layer_depth in range(depth - 2, -1, -1):
        up_convolution = get_up_convolution(pool_size=pool_size,
                                            deconvolution=deconvolution,
                                            n_filters=current_layer.shape[1])(
            current_layer)
        concat = concatenate([up_convolution, levels[layer_depth][1]], axis=1)
        current_layer = create_convolution_block(
            n_filters=levels[layer_depth][1].shape[1],
            input_layer=concat, batch_normalization=batch_normalization)
        current_layer = create_convolution_block(
            n_filters=levels[layer_depth][1].shape[1],
            input_layer=current_layer,
            batch_normalization=batch_normalization)

    final_convolution = Conv3D(n_labels, (1, 1, 1))(current_layer)
    act = Activation(activation_name)(final_convolution)
    model = Model(inputs=inputs, outputs=act)

    if not isinstance(metrics, list):
        metrics = [metrics]

    model.compile(optimizer=Adam(learning_rate=initial_learning_rate), loss=loss_function, metrics=metrics)
    return model

# %%
model = unet_model_3d(loss_function=soft_dice_loss, metrics=[mean_iou, dice_coefficient])
model.summary()

# %%
model.fit(train_generator,
        epochs=35,
        use_multiprocessing=True,
        validation_data=valid_generator
        )

# %%
# model.save_weights('/content/drive/MyDrive/Projek_Skripsi_RSU_U^2_Net_3D/3DSegmentationRSU_U^2Net++/model/weight_model_U-Net.hdf5')
# model.load_weights('/content/drive/MyDrive/Projek_Skripsi_RSU_U^2_Net_3D/3DSegmentationRSU_U^2Net++/model/weight_model_U-Net.hdf5')

# %% [markdown]
# ### CBAM RSU U^2 Net+ Architecture (Proposed Architecture)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv3D, BatchNormalization, Activation, MaxPooling3D, UpSampling3D, Concatenate, Add, GlobalAveragePooling3D, Dense, Reshape, Multiply, Lambda
tf.keras.backend.set_image_data_format('channels_first')

def conv_block(inputs, out_ch, rate=1):
    x = Conv3D(out_ch, 3, padding="same", dilation_rate=1)(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def ChannelAttention(x, reduction=16):
    channels = x.shape[1]
    avg_pool = GlobalAveragePooling3D(data_format="channels_first")(x)
    max_pool = Lambda(lambda z: tf.reduce_max(z, axis=[2, 3, 4]))(x)

    shared_dense_one = Dense(channels // reduction, activation="relu")
    shared_dense_two = Dense(channels)

    avg_out = shared_dense_two(shared_dense_one(avg_pool))
    max_out = shared_dense_two(shared_dense_one(max_pool))

    cbam_feature = Activation("sigmoid")(Add()([avg_out, max_out]))
    cbam_feature = Reshape((channels, 1, 1, 1))(cbam_feature)

    return Multiply()([x, cbam_feature])


def SpatialAttention(x):
    avg_pool = Lambda(lambda z: tf.reduce_mean(z, axis=1, keepdims=True))(x)
    max_pool = Lambda(lambda z: tf.reduce_max(z, axis=1, keepdims=True))(x)

    concat = Concatenate(axis=1)([avg_pool, max_pool])
    sa = Conv3D(1, kernel_size=7, padding="same", activation="sigmoid", data_format="channels_first")(concat)

    return Multiply()([x, sa])


def CBAM(x, reduction=16):
    x = ChannelAttention(x, reduction)
    x = SpatialAttention(x)
    return x


def RSU_L(inputs, out_ch, int_ch, num_layers, rate=2):
    x = conv_block(inputs, out_ch)
    init_feats = x

    skip = []
    x = conv_block(x, int_ch)
    skip.append(x)

    for i in range(num_layers - 2):
        x = MaxPooling3D((2, 2, 2))(x)
        x = conv_block(x, int_ch)
        skip.append(x)

    x = conv_block(x, int_ch, rate=rate)

    skip.reverse()

    x = Concatenate(axis=1)([x, skip[0]])
    x = conv_block(x, int_ch)

    for i in range(num_layers - 3):
        x = UpSampling3D(size=(2, 2, 2))(x)
        x_concat = Concatenate(axis=1)([skip[i + 1], UpSampling3D(size=(2, 2, 2))(skip[i])])
        x = Concatenate(axis=1)([x, x_concat])
        x = conv_block(x, int_ch)

    x = UpSampling3D(size=(2, 2, 2))(x)
    x = Concatenate(axis=1)([x, skip[-1]])
    x = conv_block(x, out_ch)

    x = Add()([x, init_feats])
    return x

def RSU_4F(inputs, out_ch, int_ch):
    x0 = conv_block(inputs, out_ch, rate=1)

    x1 = conv_block(x0, int_ch, rate=1)
    x2 = conv_block(x1, int_ch, rate=2)
    x3 = conv_block(x2, int_ch, rate=4)

    x4 = conv_block(x3, int_ch, rate=8)

    x = Concatenate(axis=1)([x4, x3])
    x = conv_block(x, int_ch, rate=4)

    x = Concatenate(axis=1)([x, x2])
    x = conv_block(x, int_ch, rate=2)

    x = Concatenate(axis=1)([x, x1])
    x = conv_block(x, out_ch, rate=1)

    x = Add()([x, x0])
    return x

def u2net(input_shape, out_ch, int_ch, num_classes=3):
    inputs = Input(input_shape)
    s0 = inputs

    s1 = RSU_L(s0, out_ch[0], int_ch[0], 6)
    p1 = MaxPooling3D((2, 2, 2))(s1)

    s2 = RSU_L(p1, out_ch[1], int_ch[1], 5)
    p2 = MaxPooling3D((2, 2, 2))(s2)

    s3 = RSU_L(p2, out_ch[2], int_ch[2], 4)
    p3 = MaxPooling3D((2, 2, 2))(s3)

    s4 = RSU_4F(p3, out_ch[3], int_ch[3])
    p4 = MaxPooling3D((2, 2, 2))(s4)

    b1 = RSU_4F(p4, out_ch[4], int_ch[4])
    b2 = UpSampling3D(size=(2, 2, 2))(b1)

    s4_ca = CBAM(s4)
    d1 = Concatenate(axis=1)([b2, s4_ca])
    d1 = RSU_4F(d1, out_ch[5], int_ch[5])
    u1 = UpSampling3D(size=(2, 2, 2))(d1)

    s3_ca = CBAM(s3)
    d2 = Concatenate(axis=1)([u1, s3_ca])
    d2 = RSU_L(d2, out_ch[6], int_ch[6], 4)
    u2 = UpSampling3D(size=(2, 2, 2))(d2)

    s2_ca = CBAM(s2)
    d3 = Concatenate(axis=1)([u2, s2_ca])
    d3 = RSU_L(d3, out_ch[7], int_ch[7], 5)
    u3 = UpSampling3D(size=(2, 2, 2))(d3)

    s1_ca = CBAM(s1)
    d4 = Concatenate(axis=1)([u3, s1_ca])
    d4 = RSU_L(d4, out_ch[8], int_ch[8], 6)

    y1 = Conv3D(num_classes, 3, padding="same")(d4)

    y2 = Conv3D(num_classes, 3, padding="same")(d3)
    y2 = UpSampling3D(size=(2, 2, 2))(y2)

    y3 = Conv3D(num_classes, 3, padding="same")(d2)
    y3 = UpSampling3D(size=(4, 4, 4))(y3)

    y4 = Conv3D(num_classes, 3, padding="same")(d1)
    y4 = UpSampling3D(size=(8, 8, 8))(y4)

    y5 = Conv3D(num_classes, 3, padding="same")(b1)
    y5 = UpSampling3D(size=(16, 16, 16))(y5)

    # SAM
    y6 = Concatenate(axis=1)([y1, y2, y3, y4, y5])
    y6 = SpatialAttention(y6)
    y6 = Conv3D(num_classes, 1, padding="same")(y6)
    y6 = Activation("sigmoid")(y6)

    model = tf.keras.models.Model(inputs, outputs=y6)
    return model


def build_u2net(input_shape, num_classes=3):
    out_ch = [32, 64, 128, 256, 512, 256, 128, 64, 32]
    int_ch = [32, 32, 64, 128, 256, 128, 64, 32, 32]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

# model = build_u2net((4, 160, 160, 16))
# model.summary()

# %%
# from tensorflow.keras.optimizers import Adamax
# from tensorflow.keras import callbacks
# model.compile(optimizer=Adamax(learning_rate=0.001), loss=soft_dice_loss, metrics=[mean_iou, dice_coefficient])

# %%
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

model = build_u2net(
    input_shape=(4, 160, 160, 16),
    num_classes=3
)

model.compile(
    optimizer=Adamax(learning_rate=0.00001),
    loss=soft_dice_loss,
    metrics=[mean_iou, dice_coefficient]
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 4, 160,    │          0 │ -                 │
# │ (InputLayer)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_95 (Conv3D)  │ (None, 32, 160,   │      3,488 │ input_layer_1[0]… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 160,   │         64 │ conv3d_95[0][0]   │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_89       │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_96 (Conv3D)  │ (None, 32, 160,   │     27,680 │ activation_89[0]… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 160,   │         64 │ conv3d_96[0][0]   │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_90       │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_22    │ (None, 32, 80,    │          0 │ activation_90[0]… │
# │ (MaxPooling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_97 (Conv3D)  │ (None, 32, 80,    │     27,680 │ max_pooling3d_22… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_97[0][0]   │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_91       │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_23    │ (None, 32, 40,    │          0 │ activation_91[0]… │
# │ (MaxPooling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_98 (Conv3D)  │ (None, 32, 40,    │     27,680 │ max_pooling3d_23… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_98[0][0]   │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_92       │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_24    │ (None, 32, 20,    │          0 │ activation_92[0]… │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_99 (Conv3D)  │ (None, 32, 20,    │     27,680 │ max_pooling3d_24… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_99[0][0]   │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_93       │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_25    │ (None, 32, 10,    │          0 │ activation_93[0]… │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_100 (Conv3D) │ (None, 32, 10,    │     27,680 │ max_pooling3d_25… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_100[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_94       │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_101 (Conv3D) │ (None, 32, 10,    │     27,680 │ activation_94[0]… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_101[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_95       │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_55      │ (None, 64, 10,    │          0 │ activation_95[0]… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_94[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_102 (Conv3D) │ (None, 32, 10,    │     55,328 │ concatenate_55[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_102[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_96       │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_39    │ (None, 32, 20,    │          0 │ activation_94[0]… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_38    │ (None, 32, 20,    │          0 │ activation_96[0]… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_56      │ (None, 64, 20,    │          0 │ activation_93[0]… │
# │ (Concatenate)       │ 20, 2)            │            │ up_sampling3d_39… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_57      │ (None, 96, 20,    │          0 │ up_sampling3d_38… │
# │ (Concatenate)       │ 20, 2)            │            │ concatenate_56[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_103 (Conv3D) │ (None, 32, 20,    │     82,976 │ concatenate_57[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_103[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_97       │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_41    │ (None, 32, 40,    │          0 │ activation_93[0]… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_40    │ (None, 32, 40,    │          0 │ activation_97[0]… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_58      │ (None, 64, 40,    │          0 │ activation_92[0]… │
# │ (Concatenate)       │ 40, 4)            │            │ up_sampling3d_41… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_59      │ (None, 96, 40,    │          0 │ up_sampling3d_40… │
# │ (Concatenate)       │ 40, 4)            │            │ concatenate_58[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_104 (Conv3D) │ (None, 32, 40,    │     82,976 │ concatenate_59[0… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_104[0][0]  │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_98       │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_43    │ (None, 32, 80,    │          0 │ activation_92[0]… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_42    │ (None, 32, 80,    │          0 │ activation_98[0]… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_60      │ (None, 64, 80,    │          0 │ activation_91[0]… │
# │ (Concatenate)       │ 80, 8)            │            │ up_sampling3d_43… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_61      │ (None, 96, 80,    │          0 │ up_sampling3d_42… │
# │ (Concatenate)       │ 80, 8)            │            │ concatenate_60[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_105 (Conv3D) │ (None, 32, 80,    │     82,976 │ concatenate_61[0… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_105[0][0]  │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_99       │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_44    │ (None, 32, 160,   │          0 │ activation_99[0]… │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_62      │ (None, 64, 160,   │          0 │ up_sampling3d_44… │
# │ (Concatenate)       │ 160, 16)          │            │ activation_90[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_106 (Conv3D) │ (None, 32, 160,   │     55,328 │ concatenate_62[0… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 160,   │         64 │ conv3d_106[0][0]  │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_100      │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 32, 160,   │          0 │ activation_100[0… │
# │                     │ 160, 16)          │            │ activation_89[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_26    │ (None, 32, 80,    │          0 │ add_13[0][0]      │
# │ (MaxPooling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_107 (Conv3D) │ (None, 64, 80,    │     55,360 │ max_pooling3d_26… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 80,    │         32 │ conv3d_107[0][0]  │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_101      │ (None, 64, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_108 (Conv3D) │ (None, 32, 80,    │     55,328 │ activation_101[0… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_108[0][0]  │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_102      │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_27    │ (None, 32, 40,    │          0 │ activation_102[0… │
# │ (MaxPooling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_109 (Conv3D) │ (None, 32, 40,    │     27,680 │ max_pooling3d_27… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_109[0][0]  │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_103      │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_28    │ (None, 32, 20,    │          0 │ activation_103[0… │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_110 (Conv3D) │ (None, 32, 20,    │     27,680 │ max_pooling3d_28… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_110[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_104      │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_29    │ (None, 32, 10,    │          0 │ activation_104[0… │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_111 (Conv3D) │ (None, 32, 10,    │     27,680 │ max_pooling3d_29… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_111[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_105      │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_112 (Conv3D) │ (None, 32, 10,    │     27,680 │ activation_105[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_112[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_106      │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_63      │ (None, 64, 10,    │          0 │ activation_106[0… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_105[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_113 (Conv3D) │ (None, 32, 10,    │     55,328 │ concatenate_63[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_113[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_107      │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_46    │ (None, 32, 20,    │          0 │ activation_105[0… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_45    │ (None, 32, 20,    │          0 │ activation_107[0… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_64      │ (None, 64, 20,    │          0 │ activation_104[0… │
# │ (Concatenate)       │ 20, 2)            │            │ up_sampling3d_46… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_65      │ (None, 96, 20,    │          0 │ up_sampling3d_45… │
# │ (Concatenate)       │ 20, 2)            │            │ concatenate_64[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_114 (Conv3D) │ (None, 32, 20,    │     82,976 │ concatenate_65[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_114[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_108      │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_48    │ (None, 32, 40,    │          0 │ activation_104[0… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_47    │ (None, 32, 40,    │          0 │ activation_108[0… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_66      │ (None, 64, 40,    │          0 │ activation_103[0… │
# │ (Concatenate)       │ 40, 4)            │            │ up_sampling3d_48… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_67      │ (None, 96, 40,    │          0 │ up_sampling3d_47… │
# │ (Concatenate)       │ 40, 4)            │            │ concatenate_66[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_115 (Conv3D) │ (None, 32, 40,    │     82,976 │ concatenate_67[0… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_115[0][0]  │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_109      │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_49    │ (None, 32, 80,    │          0 │ activation_109[0… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_68      │ (None, 64, 80,    │          0 │ up_sampling3d_49… │
# │ (Concatenate)       │ 80, 8)            │            │ activation_102[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_116 (Conv3D) │ (None, 64, 80,    │    110,656 │ concatenate_68[0… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 80,    │         32 │ conv3d_116[0][0]  │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_110      │ (None, 64, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 64, 80,    │          0 │ activation_110[0… │
# │                     │ 80, 8)            │            │ activation_101[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_30    │ (None, 64, 40,    │          0 │ add_14[0][0]      │
# │ (MaxPooling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_117 (Conv3D) │ (None, 128, 40,   │    221,312 │ max_pooling3d_30… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 40,   │         16 │ conv3d_117[0][0]  │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_111      │ (None, 128, 40,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_118 (Conv3D) │ (None, 64, 40,    │    221,248 │ activation_111[0… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 40,    │         16 │ conv3d_118[0][0]  │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_112      │ (None, 64, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_31    │ (None, 64, 20,    │          0 │ activation_112[0… │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_119 (Conv3D) │ (None, 64, 20,    │    110,656 │ max_pooling3d_31… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 20,    │          8 │ conv3d_119[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_113      │ (None, 64, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_32    │ (None, 64, 10,    │          0 │ activation_113[0… │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_120 (Conv3D) │ (None, 64, 10,    │    110,656 │ max_pooling3d_32… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 10,    │          4 │ conv3d_120[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_114      │ (None, 64, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_121 (Conv3D) │ (None, 64, 10,    │    110,656 │ activation_114[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 10,    │          4 │ conv3d_121[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_115      │ (None, 64, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_69      │ (None, 128, 10,   │          0 │ activation_115[0… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_114[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_122 (Conv3D) │ (None, 64, 10,    │    221,248 │ concatenate_69[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 10,    │          4 │ conv3d_122[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_116      │ (None, 64, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_51    │ (None, 64, 20,    │          0 │ activation_114[0… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_50    │ (None, 64, 20,    │          0 │ activation_116[0… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_70      │ (None, 128, 20,   │          0 │ activation_113[0… │
# │ (Concatenate)       │ 20, 2)            │            │ up_sampling3d_51… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_71      │ (None, 192, 20,   │          0 │ up_sampling3d_50… │
# │ (Concatenate)       │ 20, 2)            │            │ concatenate_70[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_123 (Conv3D) │ (None, 64, 20,    │    331,840 │ concatenate_71[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 20,    │          8 │ conv3d_123[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_117      │ (None, 64, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_52    │ (None, 64, 40,    │          0 │ activation_117[0… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_72      │ (None, 128, 40,   │          0 │ up_sampling3d_52… │
# │ (Concatenate)       │ 40, 4)            │            │ activation_112[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_124 (Conv3D) │ (None, 128, 40,   │    442,496 │ concatenate_72[0… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 40,   │         16 │ conv3d_124[0][0]  │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_118      │ (None, 128, 40,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 128, 40,   │          0 │ activation_118[0… │
# │                     │ 40, 4)            │            │ activation_111[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_33    │ (None, 128, 20,   │          0 │ add_15[0][0]      │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_125 (Conv3D) │ (None, 256, 20,   │    884,992 │ max_pooling3d_33… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 20,   │          8 │ conv3d_125[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_119      │ (None, 256, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_126 (Conv3D) │ (None, 128, 20,   │    884,864 │ activation_119[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_126[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_120      │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_127 (Conv3D) │ (None, 128, 20,   │    442,496 │ activation_120[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_127[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_121      │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_128 (Conv3D) │ (None, 128, 20,   │    442,496 │ activation_121[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_128[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_122      │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_129 (Conv3D) │ (None, 128, 20,   │    442,496 │ activation_122[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_129[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_123      │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_73      │ (None, 256, 20,   │          0 │ activation_123[0… │
# │ (Concatenate)       │ 20, 2)            │            │ activation_122[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_130 (Conv3D) │ (None, 128, 20,   │    884,864 │ concatenate_73[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_130[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_124      │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_74      │ (None, 256, 20,   │          0 │ activation_124[0… │
# │ (Concatenate)       │ 20, 2)            │            │ activation_121[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_131 (Conv3D) │ (None, 128, 20,   │    884,864 │ concatenate_74[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 20,   │          8 │ conv3d_131[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_125      │ (None, 128, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_75      │ (None, 256, 20,   │          0 │ activation_125[0… │
# │ (Concatenate)       │ 20, 2)            │            │ activation_120[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_132 (Conv3D) │ (None, 256, 20,   │  1,769,728 │ concatenate_75[0… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 20,   │          8 │ conv3d_132[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_126      │ (None, 256, 20,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 256, 20,   │          0 │ activation_126[0… │
# │                     │ 20, 2)            │            │ activation_119[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_34    │ (None, 256, 10,   │          0 │ add_16[0][0]      │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_133 (Conv3D) │ (None, 512, 10,   │  3,539,456 │ max_pooling3d_34… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 10,   │          4 │ conv3d_133[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_127      │ (None, 512, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_134 (Conv3D) │ (None, 256, 10,   │  3,539,200 │ activation_127[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_134[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_128      │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_135 (Conv3D) │ (None, 256, 10,   │  1,769,728 │ activation_128[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_135[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_129      │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_136 (Conv3D) │ (None, 256, 10,   │  1,769,728 │ activation_129[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_136[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_130      │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_137 (Conv3D) │ (None, 256, 10,   │  1,769,728 │ activation_130[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_137[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_131      │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_76      │ (None, 512, 10,   │          0 │ activation_131[0… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_130[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_138 (Conv3D) │ (None, 256, 10,   │  3,539,200 │ concatenate_76[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_138[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_132      │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ add_16[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_14 (Lambda)  │ (None, 256)       │          0 │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_77      │ (None, 512, 10,   │          0 │ activation_132[0… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_129[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 16)        │      4,112 │ global_average_p… │
# │                     │                   │            │ lambda_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_139 (Conv3D) │ (None, 256, 10,   │  3,539,200 │ concatenate_77[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 256)       │      4,352 │ dense_8[0][0],    │
# │                     │                   │            │ dense_8[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 10,   │          4 │ conv3d_139[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 256)       │          0 │ dense_9[0][0],    │
# │                     │                   │            │ dense_9[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_133      │ (None, 256, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_135      │ (None, 256)       │          0 │ add_18[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_78      │ (None, 512, 10,   │          0 │ activation_133[0… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_128[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 256, 1, 1, │          0 │ activation_135[0… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_140 (Conv3D) │ (None, 512, 10,   │  7,078,400 │ concatenate_78[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_9          │ (None, 256, 20,   │          0 │ add_16[0][0],     │
# │ (Multiply)          │ 20, 2)            │            │ reshape_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 10,   │          4 │ conv3d_140[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_15 (Lambda)  │ (None, 1, 20, 20, │          0 │ multiply_9[0][0]  │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_16 (Lambda)  │ (None, 1, 20, 20, │          0 │ multiply_9[0][0]  │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_134      │ (None, 512, 10,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_79      │ (None, 2, 20, 20, │          0 │ lambda_15[0][0],  │
# │ (Concatenate)       │ 2)                │            │ lambda_16[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 512, 10,   │          0 │ activation_134[0… │
# │                     │ 10, 1)            │            │ activation_127[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_40    │ (None, 32, 80,    │          0 │ activation_166[0… │
# │ (MaxPooling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_173 (Conv3D) │ (None, 32, 80,    │     27,680 │ max_pooling3d_40… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_173[0][0]  │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_167      │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_41    │ (None, 32, 40,    │          0 │ activation_167[0… │
# │ (MaxPooling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_174 (Conv3D) │ (None, 32, 40,    │     27,680 │ max_pooling3d_41… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_174[0][0]  │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_168      │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_42    │ (None, 32, 20,    │          0 │ activation_168[0… │
# │ (MaxPooling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_175 (Conv3D) │ (None, 32, 20,    │     27,680 │ max_pooling3d_42… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_175[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_169      │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_43    │ (None, 32, 10,    │          0 │ activation_169[0… │
# │ (MaxPooling3D)      │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_176 (Conv3D) │ (None, 32, 10,    │     27,680 │ max_pooling3d_43… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_176[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_170      │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_177 (Conv3D) │ (None, 32, 10,    │     27,680 │ activation_170[0… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_177[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_171      │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_100     │ (None, 64, 10,    │          0 │ activation_171[0… │
# │ (Concatenate)       │ 10, 1)            │            │ activation_170[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_178 (Conv3D) │ (None, 32, 10,    │     55,328 │ concatenate_100[… │
# │                     │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 10,    │          4 │ conv3d_178[0][0]  │
# │ (BatchNormalizatio… │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_172      │ (None, 32, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_66    │ (None, 32, 20,    │          0 │ activation_170[0… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_65    │ (None, 32, 20,    │          0 │ activation_172[0… │
# │ (UpSampling3D)      │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_101     │ (None, 64, 20,    │          0 │ activation_169[0… │
# │ (Concatenate)       │ 20, 2)            │            │ up_sampling3d_66… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_102     │ (None, 96, 20,    │          0 │ up_sampling3d_65… │
# │ (Concatenate)       │ 20, 2)            │            │ concatenate_101[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_179 (Conv3D) │ (None, 32, 20,    │     82,976 │ concatenate_102[… │
# │                     │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 20,    │          8 │ conv3d_179[0][0]  │
# │ (BatchNormalizatio… │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_173      │ (None, 32, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20, 2)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_68    │ (None, 32, 40,    │          0 │ activation_169[0… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_67    │ (None, 32, 40,    │          0 │ activation_173[0… │
# │ (UpSampling3D)      │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_103     │ (None, 64, 40,    │          0 │ activation_168[0… │
# │ (Concatenate)       │ 40, 4)            │            │ up_sampling3d_68… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_104     │ (None, 96, 40,    │          0 │ up_sampling3d_67… │
# │ (Concatenate)       │ 40, 4)            │            │ concatenate_103[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_180 (Conv3D) │ (None, 32, 40,    │     82,976 │ concatenate_104[… │
# │                     │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 40,    │         16 │ conv3d_180[0][0]  │
# │ (BatchNormalizatio… │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_174      │ (None, 32, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 40, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_70    │ (None, 32, 80,    │          0 │ activation_168[0… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_69    │ (None, 32, 80,    │          0 │ activation_174[0… │
# │ (UpSampling3D)      │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_105     │ (None, 64, 80,    │          0 │ activation_167[0… │
# │ (Concatenate)       │ 80, 8)            │            │ up_sampling3d_70… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_106     │ (None, 96, 80,    │          0 │ up_sampling3d_69… │
# │ (Concatenate)       │ 80, 8)            │            │ concatenate_105[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_181 (Conv3D) │ (None, 32, 80,    │     82,976 │ concatenate_106[… │
# │                     │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 80,    │         32 │ conv3d_181[0][0]  │
# │ (BatchNormalizatio… │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_175      │ (None, 32, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_71    │ (None, 32, 160,   │          0 │ activation_175[0… │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_107     │ (None, 64, 160,   │          0 │ up_sampling3d_71… │
# │ (Concatenate)       │ 160, 16)          │            │ activation_166[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_182 (Conv3D) │ (None, 32, 160,   │     55,328 │ concatenate_107[… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 160,   │         64 │ conv3d_182[0][0]  │
# │ (BatchNormalizatio… │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_176      │ (None, 32, 160,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 32, 160,   │          0 │ activation_176[0… │
# │                     │ 160, 16)          │            │ activation_165[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_184 (Conv3D) │ (None, 3, 80, 80, │      5,187 │ add_23[0][0]      │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_185 (Conv3D) │ (None, 3, 40, 40, │     10,371 │ add_21[0][0]      │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_186 (Conv3D) │ (None, 3, 20, 20, │     20,739 │ add_19[0][0]      │
# │                     │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_187 (Conv3D) │ (None, 3, 10, 10, │     41,475 │ add_17[0][0]      │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_183 (Conv3D) │ (None, 3, 160,    │      2,595 │ add_25[0][0]      │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_72    │ (None, 3, 160,    │          0 │ conv3d_184[0][0]  │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_73    │ (None, 3, 160,    │          0 │ conv3d_185[0][0]  │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_74    │ (None, 3, 160,    │          0 │ conv3d_186[0][0]  │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling3d_75    │ (None, 3, 160,    │          0 │ conv3d_187[0][0]  │
# │ (UpSampling3D)      │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_108     │ (None, 15, 160,   │          0 │ conv3d_183[0][0], │
# │ (Concatenate)       │ 160, 16)          │            │ up_sampling3d_72… │
# │                     │                   │            │ up_sampling3d_73… │
# │                     │                   │            │ up_sampling3d_74… │
# │                     │                   │            │ up_sampling3d_75… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_26 (Lambda)  │ (None, 1, 160,    │          0 │ concatenate_108[… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_27 (Lambda)  │ (None, 1, 160,    │          0 │ concatenate_108[… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_109     │ (None, 2, 160,    │          0 │ lambda_26[0][0],  │
# │ (Concatenate)       │ 160, 16)          │            │ lambda_27[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_188 (Conv3D) │ (None, 1, 160,    │        687 │ concatenate_109[… │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_17         │ (None, 15, 160,   │          0 │ concatenate_108[… │
# │ (Multiply)          │ 160, 16)          │            │ conv3d_188[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_189 (Conv3D) │ (None, 3, 160,    │         48 │ multiply_17[0][0] │
# │                     │ 160, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_177      │ (None, 3, 160,    │          0 │ conv3d_189[0][0]  │
# │ (Activation)        │ 160, 16)          │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 51,505,520 (196.48 MB)
#  Trainable params: 51,504,892 (196.48 MB)
#  Non-trainable params: 628 (2.45 KB)

# %%
model_history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 424s 927ms/step - dice_coefficient: 0.1563 - loss: 0.8437 - mean_iou: 0.1005 - val_dice_coefficient: 0.1710 - val_loss: 0.8287 - val_mean_iou: 0.1062
# Epoch 2/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 67s 212ms/step - dice_coefficient: 0.2664 - loss: 0.7336 - mean_iou: 0.1802 - val_dice_coefficient: 0.2592 - val_loss: 0.7412 - val_mean_iou: 0.1717
# Epoch 3/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 67s 213ms/step - dice_coefficient: 0.3085 - loss: 0.6915 - mean_iou: 0.2137 - val_dice_coefficient: 0.2893 - val_loss: 0.7110 - val_mean_iou: 0.1945
# Epoch 4/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 67s 211ms/step - dice_coefficient: 0.3321 - loss: 0.6679 - mean_iou: 0.2330 - val_dice_coefficient: 0.3022 - val_loss: 0.6986 - val_mean_iou: 0.2050
# Epoch 5/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 67s 211ms/step - dice_coefficient: 0.3537 - loss: 0.6463 - mean_iou: 0.2499 - val_dice_coefficient: 0.3145 - val_loss: 0.6866 - val_mean_iou: 0.2142
# Epoch 6/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 67s 211ms/step - dice_coefficient: 0.3774 - loss: 0.6226 - mean_iou: 0.2694 - val_dice_coefficient: 0.2979 - val_loss: 0.7032 - val_mean_iou: 0.2018
# Epoch 7/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 67s 211ms/step - dice_coefficient: 0.3934 - loss: 0.6066 - mean_iou: 0.2832 - val_dice_coefficient: 0.3323 - val_loss: 0.6687 - val_mean_iou: 0.2284
# Epoch 8/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 67s 211ms/step - dice_coefficient: 0.4102 - loss: 0.5898 - mean_iou: 0.2983 - val_dice_coefficient: 0.3355 - val_loss: 0.6655 - val_mean_iou: 0.2315
# Epoch 9/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 67s 210ms/step - dice_coefficient: 0.4219 - loss: 0.5781 - mean_iou: 0.3090 - val_dice_coefficient: 0.3432 - val_loss: 0.6577 - val_mean_iou: 0.2375
# Epoch 10/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 67s 209ms/step - dice_coefficient: 0.4383 - loss: 0.5617 - mean_iou: 0.3240 - val_dice_coefficient: 0.3460 - val_loss: 0.6551 - val_mean_iou: 0.2403

# %%
import pickle

with open('/content/drive/MyDrive/Kelly/RSUU2Net/model/history_cbam_u2net.pkl', 'wb') as f:
    pickle.dump(model_history.history, f)

# %%
# model.save_weights('/content/drive/MyDrive/Kelly/RSUU2Net/model/weight_model_cbam_rsu2net.weights.h5')
# model.load_weights('/content/drive/MyDrive/Kelly/RSUU2Net/model/weight_model_cbam_rsu2net.weights.h5')
# model.save('/content/drive/MyDrive/Kelly/RSUU2Net/model/pretrained_model_cbam_rsu2net.h5')

# %%
def plot_history(history):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    metric_key = 'dice_coefficient' if 'dice_coefficient' in history.history else 'accuracy'
    plt.plot(history.history[metric_key], label=f'Train {metric_key}')
    if f'val_{metric_key}' in history.history:
        plt.plot(history.history[f'val_{metric_key}'], label=f'Val {metric_key}')
    plt.title(f'{metric_key.capitalize()} over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel(metric_key.capitalize())
    plt.legend()
    plt.grid(True)

    plt.show()

plot_history(model_history)

# %% [markdown]
# ## Evaluasi Model

# %% [markdown]
# ### Dice Ceofficient dan IoU

# %%
# Proposed Architecture
test_loss, test_iou, test_dice = model.evaluate(test_ds)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 51s 694ms/step - dice_coefficient: 0.3951 - loss: 0.6052 - mean_iou: 0.2899

# %%
# # U-Net
# test_loss, test_iou, test_dice = model.evaluate(test_generator)

# %% [markdown]
# ### Recall and Specificity

# %% [markdown]
# #### 1 sub volume pada test generator

# %%
for X_sub_volume, y_sub_volume in test_ds.take(1):
    X_sub_volume = X_sub_volume.numpy()
    y_sub_volume = y_sub_volume.numpy()
    break

print("Input shape:", X_sub_volume.shape)
print("Label shape:", y_sub_volume.shape)
# Out:
# Input shape: (2, 4, 160, 160, 16)
# Label shape: (2, 3, 160, 160, 16)

# %%
print(X_sub_volume.shape)
# Out:
# (2, 4, 160, 160, 16)

# %%
satu_sub_volume_image = X_sub_volume[0]
print(satu_sub_volume_image.shape)
# Out:
# (4, 160, 160, 16)

# %%
print(y_sub_volume.shape)
# Out:
# (2, 3, 160, 160, 16)

# %%
satu_sub_volume_groundTruth = y_sub_volume[0]
print(satu_sub_volume_groundTruth.shape)
# Out:
# (3, 160, 160, 16)

# %%
X_with_batch_dimension = np.expand_dims(satu_sub_volume_image, axis=0)
data_sen_spe = model.predict(X_with_batch_dimension)
threshold = 0.5
data_sen_spe[data_sen_spe > threshold] = 1.0
data_sen_spe[data_sen_spe <= threshold] = 0.0
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step

# %%
def visualize_patch(volume, mask, slice_idx=None):
    if volume.ndim == 4:
        volume = volume[0]

    if slice_idx is None:
        slice_idx = volume.shape[-1] // 2

    img_slice = volume[:, :, slice_idx]
    mask_slice = mask[:, :, slice_idx] if mask.ndim == 3 else mask

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(img_slice, cmap="gray")
    plt.title("MRI Image")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(img_slice, cmap="gray")
    plt.imshow(mask_slice, cmap="jet", alpha=0.5)
    plt.title("Segmentation")
    plt.axis("off")

# %%
print("Sub Volume dan Mask (ground truth)")
visualize_patch(satu_sub_volume_image[0, :, :, :], satu_sub_volume_groundTruth[0])
plt.show()
print("Sub Volume dan Mask (predicton)")
visualize_patch(satu_sub_volume_image[0, :, :, :], data_sen_spe[0, 0, :, :, :])
plt.show()
# Out:
# Sub Volume dan Mask (ground truth)
# Sub Volume dan Mask (predicton)

# %%
def hitung_recall_specificity_satu_kelas(pred, label, class_num):
  class_pred = pred[class_num]
  class_label = label[class_num]
  tp = np.sum((class_pred==1) * (class_label==1))
  tn = np.sum((class_pred==0) * (class_label==0))
  fp = np.sum((class_pred==1) * (class_label==0))
  fn = np.sum((class_pred==0) * (class_label==1))
  if tp + fn == 0:
    recall = 0
  else:
      recall = tp / (tp + fn)

  if (tn + fp) == 0:
      specificity = 0
  else:
    specificity = tn / (tn + fp)
  return recall, specificity

def hitung_recall_specificity_setiap_kelas(pred, label):
  patches_matriks = pd.DataFrame(
      columns = ['Endema',
                 'Non-Enhancing Tumor',
                 'Enhancing Tumor'],
      index = ['Recall',
               'Specificity']
  )
  for i, class_name in enumerate(patches_matriks.columns):
    rec,spec = hitung_recall_specificity_satu_kelas(pred, label, i)
    patches_matriks.loc['Recall', class_name] = round(rec, 4)
    patches_matriks.loc['Specificity', class_name] = round(spec, 4)
  return patches_matriks

sens_spe = hitung_recall_specificity_setiap_kelas(data_sen_spe[0], satu_sub_volume_groundTruth)

print(sens_spe)
# Out:
#             Endema Non-Enhancing Tumor Enhancing Tumor
# Recall           0               0.283             0.0
# Specificity    1.0              0.9999          0.9999

# %% [markdown]
# #### semua sub volume pada test generator

# %%
def hitung_recall_specificity_satu_kelas(pred, label, class_num):
  class_pred = pred[class_num]
  class_label = label[class_num]
  tp = np.sum((class_pred==1) * (class_label==1))
  tn = np.sum((class_pred==0) * (class_label==0))
  fp = np.sum((class_pred==1) * (class_label==0))
  fn = np.sum((class_pred==0) * (class_label==1))
  if tp + fn == 0:
    recall = 0
  else:
      recall = tp / (tp + fn)

  if (tn + fp) == 0:
      specificity = 0
  else:
    specificity = tn / (tn + fp)
  return recall, specificity

def hitung_recall_specificity_setiap_kelas(pred, label):
  patches_matriks = pd.DataFrame(
      columns = ['Endema',
                 'Non-Enhancing Tumor',
                 'Enhancing Tumor'],
      index = ['Recall',
               'Specificity']
  )
  for i, class_name in enumerate(patches_matriks.columns):
    rec,spec = hitung_recall_specificity_satu_kelas(pred, label, i)
    patches_matriks.loc['Recall', class_name] = round(rec, 4)
    patches_matriks.loc['Specificity', class_name] = round(spec, 4)
  return patches_matriks

# %%
all_sens_spec = []

for i, (X_sub_volume, y_sub_volume) in enumerate(test_ds):
    X_sub_volume = X_sub_volume.numpy()
    y_sub_volume = y_sub_volume.numpy()

    for j in range(X_sub_volume.shape[0]):
        satu_sub_volume_image = X_sub_volume[j]
        satu_sub_volume_groundTruth = y_sub_volume[j]

        X_with_batch_dimension = np.expand_dims(satu_sub_volume_image, axis=0)
        data_sen_spe = model.predict(X_with_batch_dimension)

        threshold = 0.5
        data_sen_spe = (data_sen_spe > threshold).astype(np.float32)

        sens_spe = hitung_recall_specificity_setiap_kelas(
            data_sen_spe[0], satu_sub_volume_groundTruth
        )
        all_sens_spec.append(sens_spe)

result = pd.concat(all_sens_spec, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step

# %%
result = pd.concat(all_sens_spec, axis=1)
result_df = pd.DataFrame(result.values.T, index=result.columns, columns=result.index)

print(result_df)
# Out:
#                      Recall Specificity
# Endema                    0         1.0
# Non-Enhancing Tumor   0.283      0.9999
# Enhancing Tumor         0.0      0.9999
# Endema                    0      0.9994
# Non-Enhancing Tumor   0.719      0.9928
# ...                     ...         ...
# Non-Enhancing Tumor  0.0409       0.999
# Enhancing Tumor         0.0         1.0
# Endema               0.0304      0.9987
# Non-Enhancing Tumor  0.6127      0.9727
# Enhancing Tumor      0.6045      0.9995
#
# [375 rows x 2 columns]

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 375 entries, Endema to Enhancing Tumor
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Recall       375 non-null    object
#  1   Specificity  375 non-null    object
# dtypes: object(2)
# memory usage: 8.8+ KB

# %%
# RSU
result_df['Recall'] = result_df['Recall'].astype(float)
result_df['Specificity'] = result_df['Specificity'].astype(float)
averages = result_df.groupby(result_df.index).mean()
print(averages)
# Out:
#                        Recall  Specificity
# Endema               0.328070     0.994402
# Enhancing Tumor      0.594304     0.994590
# Non-Enhancing Tumor  0.723432     0.977342

# %%
#RSU
averages = result_df.groupby(result_df.index).mean()
recall_specificity_avg = averages.mean()
print(recall_specificity_avg)
# Out:
# Recall         0.548602
# Specificity    0.988778
# dtype: float64

# %%
# # U-Net
# result_df['Recall'] = result_df['Recall'].astype(float)
# result_df['Specificity'] = result_df['Specificity'].astype(float)
# averages = result_df.groupby(result_df.index).mean()
# print(averages)

# %%
# # U-Net
# averages = result_df.groupby(result_df.index).mean()
# recall_specificity_avg = averages.mean()
# print(recall_specificity_avg)

# %%
# result = pd.concat(all_sens_spec, axis=1)
# result.columns = ['Endema', 'Non-Enhancing Tumor', 'Enhancing Tumor'] * (len(test_generator) * X_sub_volume.shape[0])
# average_per_class = result.groupby(level=0, axis=1).mean()
# average_per_class_fix = average_per_class.reindex(columns=['Endema', 'Non-Enhancing Tumor', 'Enhancing Tumor'])
# print(average_per_class_fix)
